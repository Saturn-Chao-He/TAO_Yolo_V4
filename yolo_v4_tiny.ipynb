# %% [markdown]
# # Object Detection using TAO YOLOv4 Tiny
#
# Transfer learning is the process of transferring learned features from one application to another. It is a commonly used training technique where you use a model trained on one task and re-train to use it on a different task.
#
# Train Adapt Optimize (TAO) Toolkit  is a simple and easy-to-use Python based AI toolkit for taking purpose-built AI models and customizing them with users' own data.
#
# <img align="center" src="https://developer.nvidia.com/sites/default/files/akamai/embedded-transfer-learning-toolkit-software-stack-1200x670px.png" width="1080">

# %% [markdown]
# ## Learning Objectives
# In this notebook, you will learn how to leverage the simplicity and convenience of TAO to:
#
# * Take a pretrained model and train a YOLO v4 Tiny model on the KITTI dataset
# * Prune the trained YOLO v4 Tiny model
# * Retrain the pruned model to recover lost accuracy
# * Export the pruned model
# * Quantize the pruned model using QAT
# * Run Inference on the trained model
# * Export the pruned, quantized and retrained model to a .etlt file for deployment to DeepStream
# * Run inference on the exported .etlt model to verify deployment using TensorRT
#
# ## Table of Contents
#
# This notebook shows an example use case of YOLO v4 Tiny object detection using Train Adapt Optimize (TAO) Toolkit.
#
# 0. [Set up env variables and map drives](#head-0)
# 1. [Install the TAO launcher](#head-1)
# 2. [Prepare dataset and pre-trained model](#head-2) <br>
#      2.1 [Download the dataset](#head-2-1)<br>
#      2.2 [Verify the downloaded dataset](#head-2-2)<br>
#      2.3 [Generate tfrecords](#head-2-3)<br>
#      2.4 [Download pretrained model](#head-2-4)
# 3. [Provide training specification](#head-3)
# 4. [Run TAO training](#head-4)
# 5. [Evaluate trained models](#head-5)
# 6. [Prune trained models](#head-6)
# 7. [Retrain pruned models](#head-7)
# 8. [Evaluate retrained model](#head-8)
# 9. [Visualize inferences](#head-9)
# 10. [Model Export](#head-10)
# 11. [Verify deployed model](#head-11)

# %% [markdown]
# ## 0. Set up env variables and map drives <a class="anchor" id="head-0"></a>
#
# When using the purpose-built pretrained models from NGC, please make sure to set the `$KEY` environment variable to the key as mentioned in the model overview. Failing to do so, can lead to errors when trying to load them as pretrained models.
#
# The following notebook requires the user to set an env variable called the `$LOCAL_PROJECT_DIR` as the path to the users workspace. Please note that the dataset to run this notebook is expected to reside in the `$LOCAL_PROJECT_DIR/data`, while the TAO experiment generated collaterals will be output to `$LOCAL_PROJECT_DIR/yolo_v4_tiny`. More information on how to set up the dataset and the supported steps in the TAO workflow are provided in the subsequent cells.
#
# *Note: Please make sure to remove any stray artifacts/files from the `$USER_EXPERIMENT_DIR` or `$DATA_DOWNLOAD_DIR` paths as mentioned below, that may have been generated from previous experiments. Having checkpoint files etc may interfere with creating a training graph for a new experiment.*

# %%
# Setting up env variables for cleaner command line commands.
import os

print("Please replace the variable with your key.")
#The key is from NGC official website
# %env KEY=YzcwZDAydXZjZWY1bXNrZGdsa2hmZm91a2U6Yzk3Y2NkNzctOGZjZS00ZDcwLTljMTgtNjE2NjcyZDg2YTgw
# %env USER_EXPERIMENT_DIR=/workspace/tao-experiments/yolo_v4_tiny
# %env DATA_DOWNLOAD_DIR=/workspace/tao-experiments/data

# Set this path if you don't run the notebook from the samples directory.
# %env NOTEBOOK_ROOT=~/tao-samples/yolo_v4_tiny

# Please define this local project directory that needs to be mapped to the TAO docker session.
# The dataset expected to be present in $LOCAL_PROJECT_DIR/data, while the results for the steps
# in this notebook will be stored at $LOCAL_PROJECT_DIR/yolo_v4_tiny
#%env LOCAL_PROJECT_DIR=YOUR_LOCAL_PROJECT_DIR_PATH
# %env LOCAL_PROJECT_DIR=/home/hirain/cv_samples_v1.4.0/
os.environ["LOCAL_DATA_DIR"] = os.path.join(os.getenv("LOCAL_PROJECT_DIR", os.getcwd()), "data")
os.environ["LOCAL_EXPERIMENT_DIR"] = os.path.join(os.getenv("LOCAL_PROJECT_DIR", os.getcwd()), "yolo_v4_tiny")

# The sample spec files are present in the same path as the downloaded samples.
os.environ["LOCAL_SPECS_DIR"] = os.path.join(
    os.getenv("NOTEBOOK_ROOT", os.getcwd()),
    "specs"
)
# %env SPECS_DIR=/workspace/tao-experiments/yolo_v4_tiny/specs

# Showing list of specification files.
# !ls -rlt $LOCAL_SPECS_DIR
# Out:
# Please replace the variable with your key.
# env: KEY=YzcwZDAydXZjZWY1bXNrZGdsa2hmZm91a2U6Yzk3Y2NkNzctOGZjZS00ZDcwLTljMTgtNjE2NjcyZDg2YTgw
# env: USER_EXPERIMENT_DIR=/workspace/tao-experiments/yolo_v4_tiny
# env: DATA_DOWNLOAD_DIR=/workspace/tao-experiments/data
# env: LOCAL_PROJECT_DIR=/home/hirain/cv_samples_v1.4.0/
# env: SPECS_DIR=/workspace/tao-experiments/yolo_v4_tiny/specs
# total 28
# -rw-rw-r-- 1 hirain hirain 2316 Jun  3  2022 yolo_v4_tiny_train_kitti_seq.txt
# -rw-rw-r-- 1 hirain hirain  296 Jun  3  2022 yolo_v4_tiny_tfrecords_kitti_val.txt
# -rw-rw-r-- 1 hirain hirain  310 Jun  3  2022 yolo_v4_tiny_tfrecords_kitti_train.txt
# -rw-rw-r-- 1 hirain hirain 2306 Jun  3  2022 yolo_v4_tiny_retrain_kitti_seq.txt
# -rw-rw-r-- 1 hirain hirain 2354 Apr  5 15:58 yolo_v4_tiny_train_kitti.txt.bak
# -rw-rw-r-- 1 hirain hirain 2343 Apr  5 16:16 yolo_v4_tiny_retrain_kitti.txt
# -rw-rw-r-- 1 hirain hirain 2109 Apr  5 16:32 yolo_v4_tiny_train_kitti.txt

# %%
# Create local dir
# !mkdir -p $LOCAL_DATA_DIR
# !mkdir -p $LOCAL_EXPERIMENT_DIR

# %% [markdown]
# The cell below maps the project directory on your local host to a workspace directory in the TAO docker instance, so that the data and the results are mapped from outside to inside of the docker instance.

# %%
# Mapping up the local directories to the TAO docker.
import json
mounts_file = os.path.expanduser("~/.tao_mounts.json")

# Define the dictionary with the mapped drives
drive_map = {
    "Mounts": [
        # Mapping the data directory
        {
            "source": os.environ["LOCAL_PROJECT_DIR"],
            "destination": "/workspace/tao-experiments"
        },
        # Mapping the specs directory.
        {
            "source": os.environ["LOCAL_SPECS_DIR"],
            "destination": os.environ["SPECS_DIR"]
        },
    ]
}

# Writing the mounts file.
with open(mounts_file, "w") as mfile:
    json.dump(drive_map, mfile, indent=4)

# %%
# !cat ~/.tao_mounts.json
# Out:
# {
#     "Mounts": [
#         {
#             "source": "/home/hirain/cv_samples_v1.4.0/",
#             "destination": "/workspace/tao-experiments"
#         },
#         {
#             "source": "/home/hirain/cv_samples_v1.4.0/yolo_v4_tiny/specs",
#             "destination": "/workspace/tao-experiments/yolo_v4_tiny/specs"
#         }
#     ]
# }

# %% [markdown]
# ## 1. Install the TAO launcher <a class="anchor" id="head-1"></a>
# The TAO launcher is a python package distributed as a python wheel listed in PyPI. You may install the launcher by executing the following cell.
#
# Please note that TAO Toolkit recommends users to run the TAO launcher in a virtual env with python 3.6.9. You may follow the instruction in this [page](https://virtualenvwrapper.readthedocs.io/en/latest/install.html) to set up a python virtual env using the `virtualenv` and `virtualenvwrapper` packages. Once you have setup virtualenvwrapper, please set the version of python to be used in the virtual env by using the `VIRTUALENVWRAPPER_PYTHON` variable. You may do so by running
#
# ```sh
# export VIRTUALENVWRAPPER_PYTHON=/path/to/bin/python3.x
# ```
# where x >= 6 and <= 8
#
# We recommend performing this step first and then launching the notebook from the virtual environment. In addition to installing TAO python package, please make sure of the following software requirements:
# * python >=3.6.9 < 3.8.x
# * docker-ce > 19.03.5
# * docker-API 1.40
# * nvidia-container-toolkit > 1.3.0-1
# * nvidia-container-runtime > 3.4.0-1
# * nvidia-docker2 > 2.5.0-1
# * nvidia-driver > 455+
#
# Once you have installed the pre-requisites, please log in to the docker registry nvcr.io by following the command below
#
# ```sh
# docker login nvcr.io
# ```
#
# You will be triggered to enter a username and password. The username is `$oauthtoken` and the password is the API key generated from `ngc.nvidia.com`. Please follow the instructions in the [NGC setup guide](https://docs.nvidia.com/ngc/ngc-overview/index.html#generating-api-key) to generate your own API key.
#
# After setting up your virtual environment with the above requirements, install TAO pip package.

# %%
# SKIP this step IF you have already installed the TAO launcher.
# !pip3 install --upgrade nvidia-pyindex
# !pip3 install --upgrade nvidia-tao
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting nvidia-pyindex
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/92/59/813c065a5434541c1fff59b3a25f2767e5d176b470ef3a9b025f21edc71d/nvidia-pyindex-1.0.9.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: nvidia-pyindex
#   Building wheel for nvidia-pyindex (setup.py) ... done
#   Created wheel for nvidia-pyindex: filename=nvidia_pyindex-1.0.9-py3-none-any.whl size=8416 sha256=5d4a4bfdcb495de23e0022c90ef69289ff0d0c68b3ecdc53cc16737a20cb5bad
#   Stored in directory: /home/hirain/.cache/pip/wheels/17/f0/ea/0fd424b6ce8e07884c96b129a621dca8319cf094984cfad86b
# Successfully built nvidia-pyindex
# Installing collected packages: nvidia-pyindex
# Successfully installed nvidia-pyindex-1.0.9
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: nvidia-tao in /home/hirain/anaconda3/envs/launcher/lib/python3.6/site-packages (4.0.1)
# Requirement already satisfied: certifi in /home/hirain/anaconda3/envs/launcher/lib/python3.6/site-packages (from nvidia-tao) (2021.5.30)
# Requirement already satisfied: tabulate==0.8.7 in /home/hirain/anaconda3/envs/launcher/lib/python3.6/site-packages (from nvidia-tao) (0.8.7)
# Requirement already satisfied: requests in /home/hirain/anaconda3/envs/launcher/lib/python3.6/site-packages (from nvidia-tao) (2.27.1)
# Requirement already satisfied: idna==2.10 in /home/hirain/anaconda3/envs/launcher/lib/python3.6/site-packages (from nvidia-tao) (2.10)
# Requirement already satisfied: six==1.15.0 in /home/hirain/anaconda3/envs/launcher/lib/python3.6/site-packages (from nvidia-tao) (1.15.0)
# Requirement already satisfied: urllib3>=1.26.5 in /home/hirain/anaconda3/envs/launcher/lib/python3.6/site-packages (from nvidia-tao) (1.26.15)
# Requirement already satisfied: websocket-client==0.57.0 in /home/hirain/anaconda3/envs/launcher/lib/python3.6/site-packages (from nvidia-tao) (0.57.0)
# Requirement already satisfied: docker-pycreds==0.4.0 in /home/hirain/anaconda3/envs/launcher/lib/python3.6/site-packages (from nvidia-tao) (0.4.0)
# Requirement already satisfied: chardet==3.0.4 in /home/hirain/anaconda3/envs/launcher/lib/python3.6/site-packages (from nvidia-tao) (3.0.4)
# Requirement already satisfied: docker==4.3.1 in /home/hirain/anaconda3/envs/launcher/lib/python3.6/site-packages (from nvidia-tao) (4.3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/hirain/anaconda3/envs/launcher/lib/python3.6/site-packages (from requests->nvidia-tao) (2.0.12)

# %%
# View the versions of the TAO launcher
# !tao info --verbose
# Out:
# Configuration of the TAO Toolkit Instance
#
# dockers:
# 	nvidia/tao/tao-toolkit:
# 		4.0.0-tf2.9.1:
# 			docker_registry: nvcr.io
# 			tasks:
# 				1. classification_tf2
# 				2. efficientdet_tf2
# 		4.0.0-tf1.15.5:
# 			docker_registry: nvcr.io
# 			tasks:
# 				1. augment
# 				2. bpnet
# 				3. classification_tf1
# 				4. detectnet_v2
# 				5. dssd
# 				6. emotionnet
# 				7. efficientdet_tf1
# 				8. faster_rcnn
# 				9. fpenet
# 				10. gazenet
# 				11. gesturenet
# 				12. heartratenet
# 				13. lprnet
# 				14. mask_rcnn
# 				15. multitask_classification
# 				16. retinanet
# 				17. ssd
# 				18. unet
# 				19. yolo_v3
# 				20. yolo_v4
# 				21. yolo_v4_tiny
# 				22. converter
# 		4.0.1-tf1.15.5:
# 			docker_registry: nvcr.io
# 			tasks:
# 				1. mask_rcnn
# 				2. unet
# 		4.0.0-pyt:
# 			docker_registry: nvcr.io
# 			tasks:
# 				1. action_recognition
# 				2. deformable_detr
# 				3. segformer
# 				4. re_identification
# 				5. pointpillars
# 				6. pose_classification
# 				7. n_gram
# 				8. speech_to_text
# 				9. speech_to_text_citrinet
# 				10. speech_to_text_conformer
# 				11. spectro_gen
# 				12. vocoder
# 				13. text_classification
# 				14. question_answering
# 				15. token_classification
# 				16. intent_slot_classification
# 				17. punctuation_and_capitalization
# format_version: 2.0
# toolkit_version: 4.0.1
# published_date: 03/06/2023

# %% [markdown]
# ## 2. Prepare dataset and pre-trained model <a class="anchor" id="head-2"></a>

# %% [markdown]
#  We will be using the KITTI detection dataset for the tutorial. To find more details please visit
#  http://www.cvlibs.net/datasets/kitti/eval_object.php?obj_benchmark=2d. Please download the KITTI detection images (http://www.cvlibs.net/download.php?file=data_object_image_2.zip) and labels (http://www.cvlibs.net/download.php?file=data_object_label_2.zip) to $DATA_DOWNLOAD_DIR.
#
#  The data will then be extracted to have
#  * training images in `$LOCAL_DATA_DIR/training/image_2`
#  * training labels in `$LOCAL_DATA_DIR/training/label_2`
#  * testing images in `$LOCAL_DATA_DIR/testing/image_2`
#
# You may use this notebook with your own dataset as well. To use this example with your own dataset, please follow the same directory structure as mentioned below.
#
# *Note: There are no labels for the testing images, therefore we use it just to visualize inferences for the trained model.*

# %% [markdown]
# ### 2.1 Download the dataset <a class="anchor" id="head-2-1"></a>

# %% [markdown]
# Once you have gotten the download links in your email, please populate them in place of the `KITTI_IMAGES_DOWNLOAD_URL` and the `KITTI_LABELS_DOWNLOAD_URL`. This next cell, will download the data and place in `$LOCAL_DATA_DIR`

# %%
import os
# !mkdir -p $LOCAL_DATA_DIR
os.environ["URL_IMAGES"]=KITTI_IMAGES_DOWNLOAD_URL
# !if [ ! -f $LOCAL_DATA_DIR/data_object_image_2.zip ]; then wget $URL_IMAGES -O $LOCAL_DATA_DIR/data_object_image_2.zip; else echo "image archive already downloaded"; fi 
os.environ["URL_LABELS"]=KITTI_LABELS_DOWNLOAD_URL
# !if [ ! -f $LOCAL_DATA_DIR/data_object_label_2.zip ]; then wget $URL_LABELS -O $LOCAL_DATA_DIR/data_object_label_2.zip; else echo "label archive already downloaded"; fi

# %% [markdown]
# ### 2.2 Verify the downloaded dataset <a class="anchor" id="head-2-2"></a>

# %%
# Check the dataset is present
# !mkdir -p $LOCAL_DATA_DIR
# !if [ ! -f $LOCAL_DATA_DIR/data_object_image_2.zip ]; then echo 'Image zip file not found, please download.'; else echo 'Found Image zip file.';fi
# !if [ ! -f $LOCAL_DATA_DIR/data_object_label_2.zip ]; then echo 'Label zip file not found, please download.'; else echo 'Found Labels zip file.';fi

# %%
# This may take a while: verify integrity of zip files 
# !sha256sum $LOCAL_DATA_DIR/data_object_image_2.zip | cut -d ' ' -f 1 | grep -xq '^351c5a2aa0cd9238b50174a3a62b846bc5855da256b82a196431d60ff8d43617$' ; \
if test $? -eq 0; then echo "images OK"; else echo "images corrupt, re-download!" && rm -f $LOCAL_DATA_DIR/data_object_image_2.zip; fi 
# !sha256sum $LOCAL_DATA_DIR/data_object_label_2.zip | cut -d ' ' -f 1 | grep -xq '^4efc76220d867e1c31bb980bbf8cbc02599f02a9cb4350effa98dbb04aaed880$' ; \
if test $? -eq 0; then echo "labels OK"; else echo "labels corrupt, re-download!" && rm -f $LOCAL_DATA_DIR/data_object_label_2.zip; fi

# %%
# unpack 
# !unzip -u $LOCAL_DATA_DIR/data_object_image_2.zip -d $LOCAL_DATA_DIR
# !unzip -u $LOCAL_DATA_DIR/data_object_label_2.zip -d $LOCAL_DATA_DIR

# %%
# verify
import os

DATA_DIR = os.environ.get('LOCAL_DATA_DIR')
num_training_images = len(os.listdir(os.path.join(DATA_DIR, "training/image_2")))
num_training_labels = len(os.listdir(os.path.join(DATA_DIR, "training/label_2")))
num_testing_images = len(os.listdir(os.path.join(DATA_DIR, "testing/image_2")))
print("Number of images in the train/val set. {}".format(num_training_images))
print("Number of labels in the train/val set. {}".format(num_training_labels))
print("Number of images in the test set. {}".format(num_testing_images))

# %%
# Sample kitti label.
# !cat $LOCAL_DATA_DIR/training/label_2/000110.txt

# %%
# Generate val dataset out of training dataset
# !python3 ../ssd/generate_val_dataset.py --input_image_dir=$LOCAL_DATA_DIR/training/image_2 \
                                        --input_label_dir=$LOCAL_DATA_DIR/training/label_2 \
                                        --output_dir=$LOCAL_DATA_DIR/val

# %% [markdown]
# Additionally, if you have your own dataset already in a volume (or folder), you can mount the volume on `LOCAL_DATA_DIR` (or create a soft link). Below shows an example:
# ```bash
# # if your dataset is in /dev/sdc1
# mount /dev/sdc1 $LOCAL_DATA_DIR
#
# # if your dataset is in folder /var/dataset
# ln -sf /var/dataset $LOCAL_DATA_DIR
# ```

# %%
# If you use your own dataset, you will need to run the code below to generate the best anchor shape

# !tao yolo_v4_tiny kmeans -l $DATA_DOWNLOAD_DIR/training/label_2 \
#                          -i $DATA_DOWNLOAD_DIR/training/image_2 \
#                          -n 6 \
#                          -x 1248 \
#                          -y 384

# The anchor shape generated by this script is sorted. Write the first 3 into small_anchor_shape in the config
# file. Write middle 3 into mid_anchor_shape. Write last 3 into big_anchor_shape.

# %% [markdown]
# ### 2.3 Generate tfrecords <a class="anchor" id="head-2-3"></a>

# %% [markdown]
# The default YOLOv4 Tiny data format requires generation of TFRecords. Currently, the old sequence data format (image folders and label txt folders) is still supported and if you prefer to use the sequence data format, you can skip this section. To use sequence data format, please use spec file `yolo_v4_tiny_train_kitti_seq.txt` and `yolo_v4_tiny_retrain_kitti_seq.txt`. And you can check our user guide for more details about tfrecords generation and sequence data format usage.
#
# Note: we observe that for YOLOv4 Tiny, when mosaic augmentation is turned on (mosaic_prob > 0), the sequence format has faster training speed.
#
# Note: we observe the TFRecords format sometimes results in CUDA error during evaluation. Setting `force_on_cpu` in `nms_config` to `true` can help prevent this problem.

# %%
#!tao yolo_v4_tiny dataset_convert -d $SPECS_DIR/yolo_v4_tiny_tfrecords_kitti_train.txt \
#    -o $DATA_DOWNLOAD_DIR/training/tfrecords/train

# !tao yolo_v4_tiny dataset_convert -d /workspace/tao-experiments/data/spec-train.txt \
                                  -o /workspace/tao-experiments/data/training/tfrecords/train --gpu_index 0
# Out:
# 2023-04-05 17:53:56,987 [INFO] root: Registry: ['nvcr.io']
# 2023-04-05 17:53:57,015 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5
# 2023-04-05 17:53:57,024 [WARNING] tlt.components.docker_handler.docker_handler:
# Docker will run the commands as root. If you would like to retain your
# local host permissions, please add the "user":"UID:GID" in the
# DockerOptions portion of the "/home/hirain/.tao_mounts.json" file. You can obtain your
# users UID and GID by using the "id -u" and "id -g" commands on the
# terminal.
# Using TensorFlow backend.
# 2023-04-05 09:53:58.472609: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2023-04-05 09:54:03,164 [INFO] iva.detectnet_v2.dataio.build_converter: Instantiating a coco converter
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 2023-04-05 09:54:03,165 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Writing partition 0, shard 0
# 2023-04-05 09:54:03,167 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Writing partition 0, shard 1
# 2023-04-05 09:54:03,169 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Writing partition 0, shard 2
# 2023-04-05 09:54:03,171 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Writing partition 0, shard 3
# 2023-04-05 09:54:03,173 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Writing partition 0, shard 4
# 2023-04-05 09:54:03,174 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Writing partition 0, shard 5
# 2023-04-05 09:54:03,176 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Writing partition 0, shard 6
# 2023-04-05 09:54:03,178 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Writing partition 0, shard 7
# 2023-04-05 09:54:03,180 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Writing partition 0, shard 8
# 2023-04-05 09:54:03,181 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Writing partition 0, shard 9
# 2023-04-05 09:54:03,184 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'airpods': 101
#
# 2023-04-05 09:54:03,184 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Cumulative object statistics
# 2023-04-05 09:54:03,184 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'airpods': 101
#
# 2023-04-05 09:54:03,184 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Class map.
# Label in GT: Label in tfrecords file
# airpods: airpods
# For the dataset_config in the experiment_spec, please use labels in the tfrecords file, while writing the classmap.
#
# 2023-04-05 09:54:03,184 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Tfrecords generation complete.
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error [Errno -2] Name or service not known>
# Execution status: PASS
# 2023-04-05 17:54:05,020 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %%
#!tao yolo_v4_tiny dataset_convert -d $SPECS_DIR/yolo_v4_tiny_tfrecords_kitti_val.txt \
#                            -o $DATA_DOWNLOAD_DIR/val/tfrecords/val
# !tao yolo_v4_tiny dataset_convert -d /workspace/tao-experiments/data/spec-val.txt \
                                  -o /workspace/tao-experiments/data/val/tfrecords/val --gpu_index 0
# Out:
# 2023-04-05 17:54:31,213 [INFO] root: Registry: ['nvcr.io']
# 2023-04-05 17:54:31,241 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5
# 2023-04-05 17:54:31,251 [WARNING] tlt.components.docker_handler.docker_handler:
# Docker will run the commands as root. If you would like to retain your
# local host permissions, please add the "user":"UID:GID" in the
# DockerOptions portion of the "/home/hirain/.tao_mounts.json" file. You can obtain your
# users UID and GID by using the "id -u" and "id -g" commands on the
# terminal.
# Using TensorFlow backend.
# 2023-04-05 09:54:32.765717: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2023-04-05 09:54:37,439 [INFO] iva.detectnet_v2.dataio.build_converter: Instantiating a coco converter
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 2023-04-05 09:54:37,440 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Writing partition 0, shard 0
# 2023-04-05 09:54:37,443 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Writing partition 0, shard 1
# 2023-04-05 09:54:37,445 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'airpods': 29
#
# 2023-04-05 09:54:37,445 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Cumulative object statistics
# 2023-04-05 09:54:37,445 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'airpods': 29
#
# 2023-04-05 09:54:37,445 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Class map.
# Label in GT: Label in tfrecords file
# airpods: airpods
# For the dataset_config in the experiment_spec, please use labels in the tfrecords file, while writing the classmap.
#
# 2023-04-05 09:54:37,445 [INFO] iva.detectnet_v2.dataio.coco_converter_lib: Tfrecords generation complete.
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error [Errno -2] Name or service not known>
# Execution status: PASS
# 2023-04-05 17:54:38,565 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %% [markdown]
# ### 2.4 Download pre-trained model <a class="anchor" id="head-2-4"></a>

# %% [markdown]
# We will use NGC CLI to get the pre-trained models. For more details, go to [ngc.nvidia.com](ngc.nvidia.com) and click the SETUP on the navigation bar.

# %%
# Installing NGC CLI on the local machine.
## Download and install
# %env CLI=ngccli_cat_linux.zip
# !mkdir -p $LOCAL_PROJECT_DIR/ngccli

# Remove any previously existing CLI installations
# !rm -rf $LOCAL_PROJECT_DIR/ngccli/*
# !wget "https://ngc.nvidia.com/downloads/$CLI" -P $LOCAL_PROJECT_DIR/ngccli
# !unzip -u "$LOCAL_PROJECT_DIR/ngccli/$CLI" -d $LOCAL_PROJECT_DIR/ngccli/
# !rm $LOCAL_PROJECT_DIR/ngccli/*.zip 
os.environ["PATH"]="{}/ngccli:{}".format(os.getenv("LOCAL_PROJECT_DIR", ""), os.getenv("PATH", ""))
# Out:
# env: CLI=ngccli_cat_linux.zip
# --2023-04-05 11:31:24--  https://ngc.nvidia.com/downloads/ngccli_cat_linux.zip
# Resolving ngc.nvidia.com (ngc.nvidia.com)... 13.35.121.102, 13.35.121.39, 13.35.121.8, ...
# Connecting to ngc.nvidia.com (ngc.nvidia.com)|13.35.121.102|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42733033 (41M) [application/zip]
# Saving to: ‘/home/hirain/cv_samples_v1.4.0//ngccli/ngccli_cat_linux.zip’
#
# ngccli_cat_linux.zi 100%[===================>]  40.75M  4.14MB/s    in 11s
#
# 2023-04-05 11:31:36 (3.76 MB/s) - ‘/home/hirain/cv_samples_v1.4.0//ngccli/ngccli_cat_linux.zip’ saved [42733033/42733033]
#
# Archive:  /home/hirain/cv_samples_v1.4.0//ngccli/ngccli_cat_linux.zip
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/multidict/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/multidict/_multidict.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/libpython3.9.so.1.0
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/libkrb5support.so.0
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography-39.0.2.dist-info/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography-39.0.2.dist-info/WHEEL
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography-39.0.2.dist-info/LICENSE.APACHE
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography-39.0.2.dist-info/top_level.txt
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography-39.0.2.dist-info/LICENSE
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography-39.0.2.dist-info/INSTALLER
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography-39.0.2.dist-info/LICENSE.PSF
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography-39.0.2.dist-info/LICENSE.BSD
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography-39.0.2.dist-info/RECORD
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography-39.0.2.dist-info/METADATA
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/libgssapi_krb5.so.2
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/base_library.zip
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/certifi/
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/certifi/py.typed
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/certifi/cacert.pem
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/libfreebl3.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/libgcc_s.so.1
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/libkeyutils.so.1
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/libcom_err.so.2
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/libcrypto.so.10
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/main.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/libffi.so.6
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography/
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography/hazmat/
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography/hazmat/bindings/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography/hazmat/bindings/_rust.abi3.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/cryptography/hazmat/bindings/_openssl.abi3.so
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/prettytable-2.0.0.dist-info/
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/prettytable-2.0.0.dist-info/WHEEL
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/prettytable-2.0.0.dist-info/direct_url.json
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/prettytable-2.0.0.dist-info/REQUESTED
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/prettytable-2.0.0.dist-info/top_level.txt
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/prettytable-2.0.0.dist-info/INSTALLER
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/prettytable-2.0.0.dist-info/RECORD
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/prettytable-2.0.0.dist-info/METADATA
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/prettytable-2.0.0.dist-info/COPYING
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/pycares/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/pycares/_cares.cpython-39-x86_64-linux-gnu.so
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/thrift/
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/thrift/protocol/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/thrift/protocol/fastbinary.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/libz.so.1
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/libstdc++.so.6
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/libk5crypto.so.3
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/psutil/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/psutil/_psutil_posix.abi3.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/psutil/_psutil_linux.abi3.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/libselinux.so.1
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/importlib_metadata-5.1.0.dist-info/
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/importlib_metadata-5.1.0.dist-info/WHEEL
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/importlib_metadata-5.1.0.dist-info/direct_url.json
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/importlib_metadata-5.1.0.dist-info/REQUESTED
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/importlib_metadata-5.1.0.dist-info/top_level.txt
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/importlib_metadata-5.1.0.dist-info/LICENSE
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/importlib_metadata-5.1.0.dist-info/INSTALLER
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/importlib_metadata-5.1.0.dist-info/RECORD
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/importlib_metadata-5.1.0.dist-info/METADATA
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/jsonpickle-3.0.0.dist-info/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/jsonpickle-3.0.0.dist-info/WHEEL
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/jsonpickle-3.0.0.dist-info/direct_url.json
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/jsonpickle-3.0.0.dist-info/REQUESTED
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/jsonpickle-3.0.0.dist-info/top_level.txt
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/jsonpickle-3.0.0.dist-info/LICENSE
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/jsonpickle-3.0.0.dist-info/INSTALLER
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/jsonpickle-3.0.0.dist-info/RECORD
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/jsonpickle-3.0.0.dist-info/METADATA
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/libkrb5.so.3
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/aiohttp/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/aiohttp/_http_writer.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/aiohttp/_websocket.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/aiohttp/_helpers.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/aiohttp/_http_parser.cpython-39-x86_64-linux-gnu.so
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/wcwidth/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/wcwidth/version.json
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/ngc
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/yarl/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/yarl/_quoting_c.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/_cffi_backend.cpython-39-x86_64-linux-gnu.so
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/google/
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/google/protobuf/
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/google/protobuf/pyext/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/google/protobuf/pyext/_message.cpython-39-x86_64-linux-gnu.so
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/google/protobuf/internal/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/google/protobuf/internal/_api_implementation.cpython-39-x86_64-linux-gnu.so
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/markupsafe/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/markupsafe/_speedups.cpython-39-x86_64-linux-gnu.so
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/mmap.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_opcode.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/termios.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_codecs_jp.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_md5.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_hashlib.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_codecs_iso2022.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_socket.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/fcntl.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_elementtree.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_queue.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/select.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/resource.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_csv.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_codecs_tw.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_statistics.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_heapq.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_ssl.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_pickle.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/array.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_sha1.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/binascii.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_sha512.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/math.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_random.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_contextvars.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/zlib.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_posixsubprocess.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_datetime.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_struct.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_ctypes.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_codecs_kr.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_multiprocessing.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_sha256.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/unicodedata.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_codecs_cn.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_json.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/grp.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_posixshmem.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_bisect.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_codecs_hk.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_blake2.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/pyexpat.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_decimal.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_sha3.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_multibytecodec.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/lib-dynload/_asyncio.cpython-39-x86_64-linux-gnu.so
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/cacert.pem
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/pinpoint/
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/pinpoint/2016-12-01/
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/pinpoint/2016-12-01/endpoint-rule-set-1.json.gz
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/pinpoint/2016-12-01/service-2.json
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/pinpoint/2016-12-01/examples-1.json
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/s3outposts/
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/s3outposts/2017-07-25/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/s3outposts/2017-07-25/paginators-1.json
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/s3outposts/2017-07-25/endpoint-rule-set-1.json.gz
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/s3outposts/2017-07-25/service-2.json
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/s3outposts/2017-07-25/examples-1.json
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/resource-groups/
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/resource-groups/2017-11-27/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/resource-groups/2017-11-27/paginators-1.json
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/resource-groups/2017-11-27/endpoint-rule-set-1.json.gz
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/resource-groups/2017-11-27/service-2.json
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/resource-groups/2017-11-27/examples-1.json
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/privatenetworks/
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/privatenetworks/2021-12-03/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/privatenetworks/2021-12-03/paginators-1.json
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/privatenetworks/2021-12-03/endpoint-rule-set-1.json.gz
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/privatenetworks/2021-12-03/service-2.json
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/codecatalyst/
#    creating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/codecatalyst/2022-09-28/
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/codecatalyst/2022-09-28/paginators-1.json
#  extracting: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/codecatalyst/2022-09-28/endpoint-rule-set-1.json.gz
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/codecatalyst/2022-09-28/service-2.json
#   inflating: /home/hirain/cv_samples_v1.4.0//ngccli/ngc-cli/botocore/data/cod
UPLOA | Aug   |
# | enet_ |       |       |       |       |       | MB    | D_COM | 18,   |
# | v2    |       |       |       |       |       |       | PLETE | 2021  |
# | mobil | 79.5  | 80    | 1     | V100  | 26.2  | 26.22 | UPLOA | Aug   |
# | enet_ |       |       |       |       |       | MB    | D_COM | 18,   |
# | v1    |       |       |       |       |       |       | PLETE | 2021  |
# | googl | 77.11 | 80    | 1     | V100  | 47.6  | 47.64 | UPLOA | Aug   |
# | enet  |       |       |       |       |       | MB    | D_COM | 18,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | effic | 77.11 | 80    | 1     | V100  | 26.8  | 26.78 | UPLOA | Aug   |
# | ientn |       |       |       |       |       | MB    | D_COM | 18,   |
# | et_b1 |       |       |       |       |       |       | PLETE | 2021  |
# | _swis |       |       |       |       |       |       |       |       |
# | h     |       |       |       |       |       |       |       |       |
# | effic | 77.11 | 80    | 1     | V100  | 26.8  | 26.78 | UPLOA | Aug   |
# | ientn |       |       |       |       |       | MB    | D_COM | 18,   |
# | et_b1 |       |       |       |       |       |       | PLETE | 2021  |
# | _relu |       |       |       |       |       |       |       |       |
# | darkn | 76.44 | 80    | 1     | V100  | 311.7 | 311.6 | UPLOA | Aug   |
# | et53  |       |       |       |       |       | 8 MB  | D_COM | 18,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | darkn | 77.52 | 80    | 1     | V100  | 152.8 | 152.8 | UPLOA | Aug   |
# | et19  |       |       |       |       |       | 2 MB  | D_COM | 18,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | cspda | 77.1  | 80    | 1     | V100  | 28.6  | 28.57 | UPLOA | Nov   |
# | rknet |       |       |       |       |       | MB    | D_COM | 23,   |
# | _tiny |       |       |       |       |       |       | PLETE | 2021  |
# | cspda | 76.44 | 80    | 1     | V100  | 103.0 | 102.9 | UPLOA | Sep   |
# | rknet |       |       |       |       |       | 9 MB  | D_COM | 10,   |
# | 53    |       |       |       |       |       |       | PLETE | 2021  |
# | cspda | 77.52 | 80    | 1     | V100  | 62.9  | 62.86 | UPLOA | Sep   |
# | rknet |       |       |       |       |       | MB    | D_COM | 10,   |
# | 19    |       |       |       |       |       |       | PLETE | 2021  |
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+

# %%
# !mkdir -p $LOCAL_EXPERIMENT_DIR/pretrained_cspdarknet_tiny

# %%
# Pull pretrained model from NGC
#!ngc registry model download-version nvstaging/tao/pretrained_object_detection:cspdarknet_tiny \
#                  --dest $LOCAL_EXPERIMENT_DIR/pretrained_cspdarknet_tiny

# !ngc registry model download-version nvidia/tao/pretrained_object_detection:cspdarknet_tiny \
                  --dest $LOCAL_EXPERIMENT_DIR/pretrained_cspdarknet_tiny
# Out:
# Downloaded 26.38 MB in 22m 23s, Download speed: 20.1 KB/s
# --------------------------------------------------------------------------------
#    Transfer id: pretrained_object_detection_vcspdarknet_tiny
#    Download status: Completed
#    Downloaded local path: /home/hirain/cv_samples_v1.4.0/yolo_v4_tiny/pretrained_cspdarknet_tiny/pretrained_object_detection_vcspdarknet_tiny
#    Total files downloaded: 1
#    Total downloaded size: 26.38 MB
#    Started at: 2023-04-05 15:53:05.316463
#    Completed at: 2023-04-05 16:15:28.712430
#    Duration taken: 22m 23s
# --------------------------------------------------------------------------------

# %%
print("Check that model is downloaded into dir.")
# !ls -l $LOCAL_EXPERIMENT_DIR/pretrained_cspdarknet_tiny/pretrained_object_detection_vcspdarknet_tiny
# Out:
# Check that model is downloaded into dir.
# total 29256
# -rw------- 1 hirain hirain 29955696 Apr  5 16:15 cspdarknet_tiny.hdf5

# %% [markdown]
# ## 3. Provide training specification <a class="anchor" id="head-3"></a>
# * Augmentation parameters for on-the-fly data augmentation
# * Other training (hyper-)parameters such as batch size, number of epochs, learning rate etc.
# * Whether to use quantization aware training (QAT)

# %%
# Provide pretrained model path
# !sed -i 's,EXPERIMENT_DIR,'"$USER_EXPERIMENT_DIR"',' $LOCAL_SPECS_DIR/yolo_v4_tiny_train_kitti.txt

# To enable QAT training on sample spec file, uncomment following lines
# !sed -i "s/enable_qat: false/enable_qat: true/g" $LOCAL_SPECS_DIR/yolo_v4_tiny_train_kitti.txt
# !sed -i "s/enable_qat: false/enable_qat: true/g" $LOCAL_SPECS_DIR/yolo_v4_tiny_retrain_kitti.txt

# %%
# By default, the sample spec file disables QAT training. You can force non-QAT training by running lines below
# !sed -i "s/enable_qat: true/enable_qat: false/g" $LOCAL_SPECS_DIR/yolo_v4_tiny_train_kitti.txt
# !sed -i "s/enable_qat: true/enable_qat: false/g" $LOCAL_SPECS_DIR/yolo_v4_tiny_retrain_kitti.txt

# %%
# !cat $LOCAL_SPECS_DIR/yolo_v4_tiny_train_kitti.txt
# Out:
# random_seed: 42
# yolov4_config {
#   big_anchor_shape: "[(260.69, 172.35), (125.91, 81.47), (72.27, 42.42)]"
#   mid_anchor_shape: "[(30.80, 71.40), (38.97, 26.86), (18.88, 17.11)]"
#   box_matching_iou: 0.25
#   matching_neutral_box_iou: 0.5
#   arch: "cspdarknet_tiny"
#   loss_loc_weight: 1.0
#   loss_neg_obj_weights: 1.0
#   loss_class_weights: 1.0
#   label_smoothing: 0.0
#   big_grid_xy_extend: 0.05
#   mid_grid_xy_extend: 0.05
#   freeze_bn: false
#   #freeze_blocks: 0
#   force_relu: false
# }
# training_config {
#   visualizer {
#       enabled: False
#       num_images: 3
#   }
#   batch_size_per_gpu: 1
#   num_epochs: 80
#   enable_qat: true
#   checkpoint_interval: 10
#   learning_rate {
#     soft_start_cosine_annealing_schedule {
#       min_learning_rate: 1e-7
#       max_learning_rate: 1e-4
#       soft_start: 0.3
#     }
#   }
#   regularizer {
#     type: L1
#     weight: 3e-5
#   }
#   optimizer {
#     adam {
#       epsilon: 1e-7
#       beta1: 0.9
#       beta2: 0.999
#       amsgrad: false
#     }
#   }
#   pretrain_model_path: "/workspace/tao-experiments/yolo_v4_tiny/pretrained_cspdarknet_tiny/pretrained_object_detection_vcspdarknet_tiny/cspdarknet_tiny.hdf5"
# }
# eval_config {
#   average_precision_mode: SAMPLE
#   batch_size: 1
#   matching_iou_threshold: 0.5
# }
# nms_config {
#   confidence_threshold: 0.001
#   clustering_iou_threshold: 0.5
#   force_on_cpu: true
#   top_k: 200
# }
# augmentation_config {
#   hue: 0.1
#   saturation: 1.5
#   exposure:1.5
#   vertical_flip:0
#   horizontal_flip: 0.5
#   jitter: 0.3
#   output_width: 1248
#   output_height: 384
#   output_channel: 3
#   randomize_input_shape_period: 10
#   mosaic_prob: 0.5
#   mosaic_min_ratio:0.2
# }
# dataset_config {
#   data_sources: {
#       tfrecords_path: "/workspace/tao-experiments/data/training/tfrecords/train*"
#       image_directory_path: "/workspace/tao-experiments/data/Airpods.v1i.coco/"
#   }
#   include_difficult_in_training: true
#   image_extension: "jpg"
#   target_class_mapping {
#       key: "airpods"
#       value: "airpods"
#   }
#   validation_data_sources: {
#       tfrecords_path: "/workspace/tao-experiments/data/val/tfrecords/val*"
#       image_directory_path: "/workspace/tao-experiments/data/Airpods.v1i.coco/"
#   }
# }

# %% [markdown]
# ## 4. Run TAO training <a class="anchor" id="head-4"></a>
# * Provide the sample spec file and the output directory location for models
# * WARNING: training will take several hours or one day to complete

# %%
# !mkdir -p $LOCAL_EXPERIMENT_DIR/experiment_dir_unpruned

# %%
print("To run with multigpu, please change --gpus based on the number of available GPUs in your machine.")
# !tao yolo_v4_tiny train -e $SPECS_DIR/yolo_v4_tiny_train_kitti.txt \
                   -r $USER_EXPERIMENT_DIR/experiment_dir_unpruned \
                   -k $KEY \
                   --gpus 1
# Out:
# To run with multigpu, please change --gpus based on the number of available GPUs in your machine.
# 2023-04-05 17:56:35,838 [INFO] root: Registry: ['nvcr.io']
# 2023-04-05 17:56:35,868 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5
# 2023-04-05 17:56:35,878 [WARNING] tlt.components.docker_handler.docker_handler:
# Docker will run the commands as root. If you would like to retain your
# local host permissions, please add the "user":"UID:GID" in the
# DockerOptions portion of the "/home/hirain/.tao_mounts.json" file. You can obtain your
# users UID and GID by using the "id -u" and "id -g" commands on the
# terminal.
# Using TensorFlow backend.
# 2023-04-05 09:56:37.261785: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# INFO: Log file already exists at /workspace/tao-experiments/yolo_v4_tiny/experiment_dir_unpruned/status.json
# INFO: Starting Yolo_V4 Training job
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/third_party/keras/tensorflow_backend.py:183: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/third_party/keras/tensorflow_backend.py:183: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# INFO: Serial augmentation enabled = False
# INFO: Pseudo sharding enabled = False
# INFO: Max Image Dimensions (all sources): (0, 0)
# INFO: number of cpus: 20, io threads: 40, compute threads: 20, buffered batches: -1
# INFO: total dataset size 104, number of sources: 1, batch size per gpu: 4, steps: 26
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:Entity <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7f497c015278>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7f497c015278>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# WARNING: Entity <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7f497c015278>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7f497c015278>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# INFO: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# INFO: shuffle: True - shard 0 of 1
# INFO: sampling 1 datasets with weights:
# INFO: source: 0 weight: 1.000000
# WARNING:tensorflow:Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f497462ec88>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f497462ec88>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# WARNING: Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f497462ec88>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f497462ec88>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# INFO: Serial augmentation enabled = False
# INFO: Pseudo sharding enabled = False
# INFO: Max Image Dimensions (all sources): (0, 0)
# INFO: number of cpus: 20, io threads: 40, compute threads: 20, buffered batches: -1
# INFO: total dataset size 29, number of sources: 1, batch size per gpu: 1, steps: 29
# WARNING:tensorflow:Entity <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7f49002dd5c0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7f49002dd5c0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# WARNING: Entity <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7f49002dd5c0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7f49002dd5c0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# INFO: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# INFO: shuffle: False - shard 0 of 1
# INFO: sampling 1 datasets with weights:
# INFO: source: 0 weight: 1.000000
# WARNING:tensorflow:Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f49001086d8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f49001086d8>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# WARNING: Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f49001086d8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f49001086d8>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# INFO: Log file already exists at /workspace/tao-experiments/yolo_v4_tiny/experiment_dir_unpruned/status.json
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (None, 3, None, None 0
# __________________________________________________________________________________________________
# Input_qdq (QDQ)                 (None, 3, None, None 1           Input[0][0]
# __________________________________________________________________________________________________
# conv_0 (QuantizedConv2D)        (None, 32, None, Non 864         Input_qdq[0][0]
# __________________________________________________________________________________________________
# conv_0_bn (BatchNormalization)  (None, 32, None, Non 128         conv_0[0][0]
# __________________________________________________________________________________________________
# conv_0_mish (ReLU)              (None, 32, None, Non 0           conv_0_bn[0][0]
# __________________________________________________________________________________________________
# conv_0_mish_qdq (QDQ)           (None, 32, None, Non 1           conv_0_mish[0][0]
# __________________________________________________________________________________________________
# conv_1 (QuantizedConv2D)        (None, 64, None, Non 18432       conv_0_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_1_bn (BatchNormalization)  (None, 64, None, Non 256         conv_1[0][0]
# __________________________________________________________________________________________________
# conv_1_mish (ReLU)              (None, 64, None, Non 0           conv_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_1_mish_qdq (QDQ)           (None, 64, None, Non 1           conv_1_mish[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_0 (QuantizedConv2D) (None, 64, None, Non 36864       conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_0_bn (BatchNormaliz (None, 64, None, Non 256         conv_2_conv_0[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_0_mish (ReLU)       (None, 64, None, Non 0           conv_2_conv_0_bn[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_0_mish_qdq (QDQ)    (None, 64, None, Non 1           conv_2_conv_0_mish[0][0]
# __________________________________________________________________________________________________
# conv_2_split_0 (Split)          (None, 32, None, Non 0           conv_2_conv_0_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_split_0_qdq (QDQ)        (None, 32, None, Non 1           conv_2_split_0[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_1 (QuantizedConv2D) (None, 32, None, Non 9216        conv_2_split_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_1_bn (BatchNormaliz (None, 32, None, Non 128         conv_2_conv_1[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_1_mish (ReLU)       (None, 32, None, Non 0           conv_2_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_1_mish_qdq (QDQ)    (None, 32, None, Non 1           conv_2_conv_1_mish[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_2 (QuantizedConv2D) (None, 32, None, Non 9216        conv_2_conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_2_bn (BatchNormaliz (None, 32, None, Non 128         conv_2_conv_2[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_2_mish (ReLU)       (None, 32, None, Non 0           conv_2_conv_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_2_mish_qdq (QDQ)    (None, 32, None, Non 1           conv_2_conv_2_mish[0][0]
# __________________________________________________________________________________________________
# conv_2_concat_0 (Concatenate)   (None, 64, None, Non 0           conv_2_conv_2_mish_qdq[0][0]
#                                                                  conv_2_conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_concat_0_qdq (QDQ)       (None, 64, None, Non 1           conv_2_concat_0[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_3 (QuantizedConv2D) (None, 64, None, Non 4096        conv_2_concat_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_3_bn (BatchNormaliz (None, 64, None, Non 256         conv_2_conv_3[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_3_mish (ReLU)       (None, 64, None, Non 0           conv_2_conv_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_3_mish_qdq (QDQ)    (None, 64, None, Non 1           conv_2_conv_3_mish[0][0]
# __________________________________________________________________________________________________
# conv_2_concat_1 (Concatenate)   (None, 128, None, No 0           conv_2_conv_0_mish_qdq[0][0]
#                                                                  conv_2_conv_3_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_concat_1_qdq (QDQ)       (None, 128, None, No 1           conv_2_concat_1[0][0]
# __________________________________________________________________________________________________
# conv_2_pool_0 (MaxPooling2D)    (None, 128, None, No 0           conv_2_concat_1_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_pool_0_qdq (QDQ)         (None, 128, None, No 1           conv_2_pool_0[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_0 (QuantizedConv2D) (None, 128, None, No 147456      conv_2_pool_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_0_bn (BatchNormaliz (None, 128, None, No 512         conv_3_conv_0[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_0_mish (ReLU)       (None, 128, None, No 0           conv_3_conv_0_bn[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_0_mish_qdq (QDQ)    (None, 128, None, No 1           conv_3_conv_0_mish[0][0]
# __________________________________________________________________________________________________
# conv_3_split_0 (Split)          (None, 64, None, Non 0           conv_3_conv_0_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_split_0_qdq (QDQ)        (None, 64, None, Non 1           conv_3_split_0[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_1 (QuantizedConv2D) (None, 64, None, Non 36864       conv_3_split_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_1_bn (BatchNormaliz (None, 64, None, Non 256         conv_3_conv_1[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_1_mish (ReLU)       (None, 64, None, Non 0           conv_3_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_1_mish_qdq (QDQ)    (None, 64, None, Non 1           conv_3_conv_1_mish[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_2 (QuantizedConv2D) (None, 64, None, Non 36864       conv_3_conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_2_bn (BatchNormaliz (None, 64, None, Non 256         conv_3_conv_2[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_2_mish (ReLU)       (None, 64, None, Non 0           conv_3_conv_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_2_mish_qdq (QDQ)    (None, 64, None, Non 1           conv_3_conv_2_mish[0][0]
# __________________________________________________________________________________________________
# conv_3_concat_0 (Concatenate)   (None, 128, None, No 0           conv_3_conv_2_mish_qdq[0][0]
#                                                                  conv_3_conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_concat_0_qdq (QDQ)       (None, 128, None, No 1           conv_3_concat_0[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_3 (QuantizedConv2D) (None, 128, None, No 16384       conv_3_concat_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_3_bn (BatchNormaliz (None, 128, None, No 512         conv_3_conv_3[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_3_mish (ReLU)       (None, 128, None, No 0           conv_3_conv_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_3_mish_qdq (QDQ)    (None, 128, None, No 1           conv_3_conv_3_mish[0][0]
# __________________________________________________________________________________________________
# conv_3_concat_1 (Concatenate)   (None, 256, None, No 0           conv_3_conv_0_mish_qdq[0][0]
#                                                                  conv_3_conv_3_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_concat_1_qdq (QDQ)       (None, 256, None, No 1           conv_3_concat_1[0][0]
# __________________________________________________________________________________________________
# conv_3_pool_0 (MaxPooling2D)    (None, 256, None, No 0           conv_3_concat_1_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_pool_0_qdq (QDQ)         (None, 256, None, No 1           conv_3_pool_0[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_0 (QuantizedConv2D) (None, 256, None, No 589824      conv_3_pool_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_0_bn (BatchNormaliz (None, 256, None, No 1024        conv_4_conv_0[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_0_mish (ReLU)       (None, 256, None, No 0           conv_4_conv_0_bn[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_0_mish_qdq (QDQ)    (None, 256, None, No 1           conv_4_conv_0_mish[0][0]
# __________________________________________________________________________________________________
# conv_4_split_0 (Split)          (None, 128, None, No 0           conv_4_conv_0_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_split_0_qdq (QDQ)        (None, 128, None, No 1           conv_4_split_0[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_1 (QuantizedConv2D) (None, 128, None, No 147456      conv_4_split_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_1_bn (BatchNormaliz (None, 128, None, No 512         conv_4_conv_1[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_1_mish (ReLU)       (None, 128, None, No 0           conv_4_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_1_mish_qdq (QDQ)    (None, 128, None, No 1           conv_4_conv_1_mish[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_2 (QuantizedConv2D) (None, 128, None, No 147456      conv_4_conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_2_bn (BatchNormaliz (None, 128, None, No 512         conv_4_conv_2[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_2_mish (ReLU)       (None, 128, None, No 0           conv_4_conv_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_2_mish_qdq (QDQ)    (None, 128, None, No 1           conv_4_conv_2_mish[0][0]
# __________________________________________________________________________________________________
# conv_4_concat_0 (Concatenate)   (None, 256, None, No 0           conv_4_conv_2_mish_qdq[0][0]
#                                                                  conv_4_conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_concat_0_qdq (QDQ)       (None, 256, None, No 1           conv_4_concat_0[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_3 (QuantizedConv2D) (None, 256, None, No 65536       conv_4_concat_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_3_bn (BatchNormaliz (None, 256, None, No 1024        conv_4_conv_3[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_3_mish (ReLU)       (None, 256, None, No 0           conv_4_conv_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_3_mish_qdq (QDQ)    (None, 256, None, No 1           conv_4_conv_3_mish[0][0]
# __________________________________________________________________________________________________
# conv_4_concat_1 (Concatenate)   (None, 512, None, No 0           conv_4_conv_0_mish_qdq[0][0]
#                                                                  conv_4_conv_3_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_concat_1_qdq (QDQ)       (None, 512, None, No 1           conv_4_concat_1[0][0]
# __________________________________________________________________________________________________
# conv_4_pool_0 (MaxPooling2D)    (None, 512, None, No 0           conv_4_concat_1_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_pool_0_qdq (QDQ)         (None, 512, None, No 1           conv_4_pool_0[0][0]
# __________________________________________________________________________________________________
# conv_5 (QuantizedConv2D)        (None, 512, None, No 2359296     conv_4_pool_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_5_bn (BatchNormalization)  (None, 512, None, No 2048        conv_5[0][0]
# __________________________________________________________________________________________________
# conv_5_mish (ReLU)              (None, 512, None, No 0           conv_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_5_mish_qdq (QDQ)           (None, 512, None, No 1           conv_5_mish[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_1 (QuantizedConv2D)  (None, 256, None, No 131072      conv_5_mish_qdq[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_1_bn (BatchNormaliza (None, 256, None, No 1024        yolo_conv1_1[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_1_lrelu (ReLU)       (None, 256, None, No 0           yolo_conv1_1_bn[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_1_lrelu_qdq (QDQ)    (None, 256, None, No 1           yolo_conv1_1_lrelu[0][0]
# __________________________________________________________________________________________________
# yolo_conv2 (QuantizedConv2D)    (None, 128, None, No 32768       yolo_conv1_1_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# yolo_conv2_bn (BatchNormalizati (None, 128, None, No 512         yolo_conv2[0][0]
# __________________________________________________________________________________________________
# yolo_conv2_lrelu (ReLU)         (None, 128, None, No 0           yolo_conv2_bn[0][0]
# __________________________________________________________________________________________________
# yolo_conv2_lrelu_qdq (QDQ)      (None, 128, None, No 1           yolo_conv2_lrelu[0][0]
# __________________________________________________________________________________________________
# upsample0 (UpSampling2D)        (None, 128, None, No 0           yolo_conv2_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# upsample0_qdq (QDQ)             (None, 128, None, No 1           upsample0[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 384, None, No 0           upsample0_qdq[0][0]
#                                                                  conv_4_conv_3_mish_qdq[0][0]
# __________________________________________________________________________________________________
# concatenate_2_qdq (QDQ)         (None, 384, None, No 1           concatenate_2[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_6 (QuantizedConv2D)  (None, 512, None, No 1179648     yolo_conv1_1_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# yolo_conv3_6 (QuantizedConv2D)  (None, 256, None, No 884736      concatenate_2_qdq[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_6_bn (BatchNormaliza (None, 512, None, No 2048        yolo_conv1_6[0][0]
# __________________________________________________________________________________________________
# yolo_conv3_6_bn (BatchNormaliza (None, 256, None, No 1024        yolo_conv3_6[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_6_lrelu (ReLU)       (None, 512, None, No 0           yolo_conv1_6_bn[0][0]
# __________________________________________________________________________________________________
# yolo_conv3_6_lrelu (ReLU)       (None, 256, None, No 0           yolo_conv3_6_bn[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_6_lrelu_qdq (QDQ)    (None, 512, None, No 1           yolo_conv1_6_lrelu[0][0]
# __________________________________________________________________________________________________
# yolo_conv3_6_lrelu_qdq (QDQ)    (None, 256, None, No 1           yolo_conv3_6_lrelu[0][0]
# __________________________________________________________________________________________________
# conv_big_object (Conv2D)        (None, 18, None, Non 9234        yolo_conv1_6_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# conv_mid_object (Conv2D)        (None, 18, None, Non 4626        yolo_conv3_6_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# bg_permute (Permute)            (None, None, None, 1 0           conv_big_object[0][0]
# __________________________________________________________________________________________________
# md_permute (Permute)            (None, None, None, 1 0           conv_mid_object[0][0]
# __________________________________________________________________________________________________
# bg_reshape (Reshape)            (None, None, 6)      0           bg_permute[0][0]
# __________________________________________________________________________________________________
# md_reshape (Reshape)            (None, None, 6)      0           md_permute[0][0]
# __________________________________________________________________________________________________
# bg_anchor (YOLOAnchorBox)       (None, None, 6)      0           conv_big_object[0][0]
# __________________________________________________________________________________________________
# bg_bbox_processor (BBoxPostProc (None, None, 6)      0           bg_reshape[0][0]
# __________________________________________________________________________________________________
# md_anchor (YOLOAnchorBox)       (None, None, 6)      0           conv_mid_object[0][0]
# __________________________________________________________________________________________________
# md_bbox_processor (BBoxPostProc (None, None, 6)      0           md_reshape[0][0]
# __________________________________________________________________________________________________
# encoded_bg (Concatenate)        (None, None, 12)     0           bg_anchor[0][0]
#                                                                  bg_bbox_processor[0][0]
# __________________________________________________________________________________________________
# encoded_md (Concatenate)        (None, None, 12)     0           md_anchor[0][0]
#                                                                  md_bbox_processor[0][0]
# __________________________________________________________________________________________________
# encoded_detections (Concatenate (None, None, 12)     0           encoded_bg[0][0]
#                                                                  encoded_md[0][0]
# ==================================================================================================
# Total params: 5,880,358
# Trainable params: 5,874,116
# Non-trainable params: 6,242
# __________________________________________________________________________________________________
# INFO: Starting Training Loop.
# Epoch 1/80
# 104/104 [==============================] - 67s 640ms/step - loss: 4168.8842
# ac55251a1b7d:168:231 [0] NCCL INFO Bootstrap : Using eth0:172.17.0.4<0>
# ac55251a1b7d:168:231 [0] NCCL INFO NET/Plugin: Failed to find ncclNetPlugin_v6 symbol.
# ac55251a1b7d:168:231 [0] NCCL INFO NET/Plugin: Loaded net plugin NCCL RDMA Plugin (v5)
# ac55251a1b7d:168:231 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v6 symbol.
# ac55251a1b7d:168:231 [0] NCCL INFO NET/Plugin: Loaded coll plugin SHARP (v5)
# ac55251a1b7d:168:231 [0] NCCL INFO cudaDriverVersion 11010
# NCCL version 2.15.1+cuda11.8
# ac55251a1b7d:168:231 [0] NCCL INFO Plugin Path : /opt/hpcx/nccl_rdma_sharp_plugin/lib/libnccl-net.so
# ac55251a1b7d:168:231 [0] NCCL INFO P2P plugin IBext
# ac55251a1b7d:168:231 [0] NCCL INFO NET/IB : No device found.
# ac55251a1b7d:168:231 [0] NCCL INFO NET/IB : No device found.
# ac55251a1b7d:168:231 [0] NCCL INFO NET/Socket : Using [0]eth0:172.17.0.4<0>
# ac55251a1b7d:168:231 [0] NCCL INFO Using network Socket
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 00/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 01/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 02/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 03/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 04/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 05/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 06/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 07/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 08/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 09/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 10/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 11/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 12/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 13/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 14/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 15/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 16/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 17/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 18/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 19/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 20/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 21/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 22/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 23/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 24/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 25/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 26/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 27/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 28/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 29/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 30/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Channel 31/32 :    0
# ac55251a1b7d:168:231 [0] NCCL INFO Trees [0] -1/-1/-1->0->-1 [1] -1/-1/-1->0->-1 [2] -1/-1/-1->0->-1 [3] -1/-1/-1->0->-1 [4] -1/-1/-1->0->-1 [5] -1/-1/-1->0->-1 [6] -1/-1/-1->0->-1 [7] -1/-1/-1->0->-1 [8] -1/-1/-1->0->-1 [9] -1/-1/-1->0->-1 [10] -1/-1/-1->0->-1 [11] -1/-1/-1->0->-1 [12] -1/-1/-1->0->-1 [13] -1/-1/-1->0->-1 [14] -1/-1/-1->0->-1 [15] -1/-1/-1->0->-1 [16] -1/-1/-1->0->-1 [17] -1/-1/-1->0->-1 [18] -1/-1/-1->0->-1 [19] -1/-1/-1->0->-1 [20] -1/-1/-1->0->-1 [21] -1/-1/-1->0->-1 [22] -1/-1/-1->0->-1 [23] -1/-1/-1->0->-1 [24] -1/-1/-1->0->-1 [25] -1/-1/-1->0->-1 [26] -1/-1/-1->0->-1 [27] -1/-1/-1->0->-1 [28] -1/-1/-1->0->-1 [29] -1/-1/-1->0->-1 [30] -1/-1/-1->0->-1 [31] -1/-1/-1->0->-1
# ac55251a1b7d:168:231 [0] NCCL INFO Connected all rings
# ac55251a1b7d:168:231 [0] NCCL INFO Connected all trees
# ac55251a1b7d:168:231 [0] NCCL INFO 32 coll channels, 32 p2p channels, 32 p2p channels per peer
# ac55251a1b7d:168:231 [0] NCCL INFO comm 0x7f49c84e1030 rank 0 nranks 1 cudaDev 0 busId 1000 - Init COMPLETE
# INFO: Training loop in progress
# Epoch 2/80
# 104/104 [==============================] - 49s 474ms/step - loss: 4580.6791
# INFO: Training loop in progress
# Epoch 3/80
# 104/104 [==============================] - 52s 499ms/step - loss: 4200.3927
# INFO: Training loop in progress
# Epoch 4/80
# 104/104 [==============================] - 50s 477ms/step - loss: 3805.0323
# INFO: Training loop in progress
# Epoch 5/80
# 104/104 [==============================] - 50s 482ms/step - loss: 2240.1449
# INFO: Training loop in progress
# Epoch 6/80
# 104/104 [==============================] - 49s 475ms/step - loss: 2604.8767
# INFO: Training loop in progress
# Epoch 7/80
# 104/104 [==============================] - 47s 449ms/step - loss: 1396.5005
# INFO: Training loop in progress
# Epoch 8/80
# 104/104 [==============================] - 47s 455ms/step - loss: 1295.8349
# INFO: Training loop in progress
# Epoch 9/80
# 104/104 [==============================] - 43s 410ms/step - loss: 1034.1371
# INFO: Training loop in progress
# Epoch 10/80
# 104/104 [==============================] - 52s 497ms/step - loss: 556.0489
# Producing predictions: 100%|████████████████████| 29/29 [00:03<00:00,  9.36it/s]
# Start to calculate AP for each class
# *******************************
# airpods       AP    0
o $USER_EXPERIMENT_DIR/experiment_dir_pruned/yolov4_cspdarknet_tiny_pruned.tlt \
                   -eq intersection \
                   -pth 0.1 \
                   -k $KEY
# Out:
# 2023-04-06 10:24:04,756 [INFO] root: Registry: ['nvcr.io']
# 2023-04-06 10:24:05,205 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5
# 2023-04-06 10:24:05,492 [WARNING] tlt.components.docker_handler.docker_handler:
# Docker will run the commands as root. If you would like to retain your
# local host permissions, please add the "user":"UID:GID" in the
# DockerOptions portion of the "/home/hirain/.tao_mounts.json" file. You can obtain your
# users UID and GID by using the "id -u" and "id -g" commands on the
# terminal.
# Using TensorFlow backend.
# 2023-04-06 02:24:22.053270: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2023-04-06 02:24:52,920 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:131: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2023-04-06 02:24:53,072 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:131: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2023-04-06 02:24:53,072 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2023-04-06 02:24:53,073 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# 2023-04-06 02:24:53,089 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 2023-04-06 02:24:53,140 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 2023-04-06 02:24:53,155 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,180 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,204 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,207 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,232 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,257 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,260 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,284 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,287 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/third_party/keras/tensorflow_backend.py:183: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 2023-04-06 02:24:53,288 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/third_party/keras/tensorflow_backend.py:183: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 2023-04-06 02:24:53,291 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,315 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,319 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,343 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,368 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,370 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,395 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,398 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,400 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,425 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,428 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,452 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,477 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,480 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,504 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,507 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,509 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,534 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,559 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,583 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# 2023-04-06 02:24:53,586 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# 2023-04-06 02:24:53,589 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,591 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,638 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:24:53,640 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# 2023-04-06 02:24:53,832 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2023-04-06 02:24:53,832 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2023-04-06 02:24:53,833 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2023-04-06 02:25:04,678 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# 2023-04-06 02:25:04,678 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2023-04-06 02:25:05,181 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# 2023-04-06 02:25:05,604 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# 2023-04-06 02:25:06,969 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# 2023-04-06 02:25:07,267 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# 2023-04-06 02:25:09,029 [INFO] modulus.pruning.pruning: Exploring graph for retainable indices
# 2023-04-06 02:25:10,768 [INFO] modulus.pruning.pruning: Pruning model and appending pruned nodes to new graph
# 2023-04-06 02:25:10,770 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:12,598 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:14,677 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:16,696 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:16,699 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:18,619 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:20,549 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:20,552 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:22,782 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:22,785 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:22,787 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:24,946 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:24,950 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:26,997 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:29,060 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:29,063 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:31,176 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:31,179 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:31,182 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:33,430 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:33,433 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:35,552 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:37,741 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:37,744 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:39,942 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:39,945 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:39,948 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:42,215 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:44,494 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:48,613 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:48,615 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:50,050 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:50,061 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:52,691 [WARNING] modulus.models.templates.qdq_layer: QDQ: Keras learning_phase was not set. Assuming evaluation phase.
# 2023-04-06 02:25:54,169 [INFO] __main__: Pruning ratio (pruned model / original model): 1.0
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error [Errno -2] Name or service not known>
# Execution status: PASS
# 2023-04-06 10:26:04,317 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %%
# !ls -rlt $LOCAL_EXPERIMENT_DIR/experiment_dir_pruned/
# Out:
# total 23268
# -rw-r--r-- 1 root root 23826312 Apr  6 10:25 yolov4_cspdarknet_tiny_pruned.tlt

# %% [markdown]
# ## 7. Retrain pruned models <a class="anchor" id="head-7"></a>
# * Model needs to be re-trained to bring back accuracy after pruning
# * Specify re-training specification
# * WARNING: training will take several hours or one day to complete

# %%
# Printing the retrain spec file. 
# Here we have updated the spec file to include the newly pruned model as a pretrained weights.
# !sed -i 's,EXPERIMENT_DIR,'"$USER_EXPERIMENT_DIR"',' $LOCAL_SPECS_DIR/yolo_v4_tiny_retrain_kitti.txt
# !cat $LOCAL_SPECS_DIR/yolo_v4_tiny_retrain_kitti.txt
# Out:
# random_seed: 42
# yolov4_config {
#   big_anchor_shape: "[(260.69, 172.35), (125.91, 81.47), (72.27, 42.42)]"
#   mid_anchor_shape: "[(30.80, 71.40), (38.97, 26.86), (18.88, 17.11)]"
#   box_matching_iou: 0.25
#   matching_neutral_box_iou: 0.5
#   arch: "cspdarknet_tiny"
#   loss_loc_weight: 1.0
#   loss_neg_obj_weights: 1.0
#   loss_class_weights: 1.0
#   label_smoothing: 0.0
#   big_grid_xy_extend: 0.05
#   mid_grid_xy_extend: 0.05
#   freeze_bn: false
#   #freeze_blocks: 0
#   force_relu: false
# }
# training_config {
#   visualizer {
#       enabled: False
#       num_images: 3
#   }
#   batch_size_per_gpu: 8
#   num_epochs: 80
#   enable_qat: true
#   checkpoint_interval: 10
#   learning_rate {
#     soft_start_cosine_annealing_schedule {
#       min_learning_rate: 1e-7
#       max_learning_rate: 1e-4
#       soft_start: 0.3
#     }
#   }
#   regularizer {
#     type: NO_REG
#     weight: 3e-9
#   }
#   optimizer {
#     adam {
#       epsilon: 1e-7
#       beta1: 0.9
#       beta2: 0.999
#       amsgrad: false
#     }
#   }
#   pruned_model_path: "/workspace/tao-experiments/yolo_v4_tiny/experiment_dir_pruned/yolov4_cspdarknet_tiny_pruned.tlt"
# }
# eval_config {
#   average_precision_mode: SAMPLE
#   batch_size: 8
#   matching_iou_threshold: 0.5
# }
# nms_config {
#   confidence_threshold: 0.001
#   clustering_iou_threshold: 0.5
#   top_k: 200
#   force_on_cpu: true
# }
# augmentation_config {
#   hue: 0.1
#   saturation: 1.5
#   exposure:1.5
#   vertical_flip:0
#   horizontal_flip: 0.5
#   jitter: 0.3
#   output_width: 1248
#   output_height: 384
#   output_channel: 3
#   randomize_input_shape_period: 10
#   mosaic_prob: 0.5
#   mosaic_min_ratio:0.2
# }
# dataset_config {
#   data_sources: {
#       tfrecords_path: "/workspace/tao-experiments/data/training/tfrecords/train*"
#       image_directory_path: "/workspace/tao-experiments/data/training"
#   }
#   include_difficult_in_training: true
#   image_extension: "png"
#   target_class_mapping {
#       key: "car"
#       value: "car"
#   }
#   target_class_mapping {
#       key: "pedestrian"
#       value: "pedestrian"
#   }
#   target_class_mapping {
#       key: "cyclist"
#       value: "cyclist"
#   }
#   target_class_mapping {
#       key: "van"
#       value: "car"
#   }
#   target_class_mapping {
#       key: "person_sitting"
#       value: "pedestrian"
#   }
#   validation_data_sources: {
#       tfrecords_path: "/workspace/tao-experiments/data/val/tfrecords/val*"
#       image_directory_path: "/workspace/tao-experiments/data/val"
#   }
# }

# %%
# !mkdir -p $LOCAL_EXPERIMENT_DIR/experiment_dir_retrain

# %%
# Retraining using the pruned model as pretrained weights 
# !tao yolo_v4_tiny train --gpus 1 \
                   -e $SPECS_DIR/yolo_v4_tiny_retrain_kitti.txt \
                   -r $USER_EXPERIMENT_DIR/experiment_dir_retrain \
                   -k $KEY
# Out:
# 2023-04-06 10:49:35,523 [INFO] root: Registry: ['nvcr.io']
# 2023-04-06 10:49:35,552 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5
# 2023-04-06 10:49:35,571 [WARNING] tlt.components.docker_handler.docker_handler:
# Docker will run the commands as root. If you would like to retain your
# local host permissions, please add the "user":"UID:GID" in the
# DockerOptions portion of the "/home/hirain/.tao_mounts.json" file. You can obtain your
# users UID and GID by using the "id -u" and "id -g" commands on the
# terminal.
# Using TensorFlow backend.
# 2023-04-06 02:49:37.018687: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# INFO: Starting Yolo_V4 Training job
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/third_party/keras/tensorflow_backend.py:183: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/third_party/keras/tensorflow_backend.py:183: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# INFO: Serial augmentation enabled = False
# INFO: Pseudo sharding enabled = False
# INFO: Max Image Dimensions (all sources): (0, 0)
# INFO: number of cpus: 20, io threads: 40, compute threads: 20, buffered batches: -1
# INFO: total dataset size 104, number of sources: 1, batch size per gpu: 4, steps: 26
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:Entity <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7fcf74120400>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7fcf74120400>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# WARNING: Entity <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7fcf74120400>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7fcf74120400>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# INFO: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# INFO: shuffle: True - shard 0 of 1
# INFO: sampling 1 datasets with weights:
# INFO: source: 0 weight: 1.000000
# WARNING:tensorflow:Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7fcf44695390>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7fcf44695390>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# WARNING: Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7fcf44695390>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7fcf44695390>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# INFO: Serial augmentation enabled = False
# INFO: Pseudo sharding enabled = False
# INFO: Max Image Dimensions (all sources): (0, 0)
# INFO: number of cpus: 20, io threads: 40, compute threads: 20, buffered batches: -1
# INFO: total dataset size 29, number of sources: 1, batch size per gpu: 1, steps: 29
# WARNING:tensorflow:Entity <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7fcefc60f240>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7fcefc60f240>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# WARNING: Entity <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7fcefc60f240>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7fcefc60f240>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# INFO: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# INFO: shuffle: False - shard 0 of 1
# INFO: sampling 1 datasets with weights:
# INFO: source: 0 weight: 1.000000
# WARNING:tensorflow:Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7fcefc4394e0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7fcefc4394e0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# WARNING: Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7fcefc4394e0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7fcefc4394e0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# INFO: Log file already exists at /workspace/tao-experiments/yolo_v4_tiny/experiment_dir_retrain/status.json
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (1, 3, None, None)   0
# __________________________________________________________________________________________________
# Input_qdq (QDQ)                 (1, 3, None, None)   1           Input[0][0]
# __________________________________________________________________________________________________
# conv_0 (QuantizedConv2D)        (1, 32, None, None)  864         Input_qdq[0][0]
# __________________________________________________________________________________________________
# conv_0_bn (BatchNormalization)  (1, 32, None, None)  128         conv_0[0][0]
# __________________________________________________________________________________________________
# conv_0_mish (ReLU)              (1, 32, None, None)  0           conv_0_bn[0][0]
# __________________________________________________________________________________________________
# conv_0_mish_qdq (QDQ)           (1, 32, None, None)  1           conv_0_mish[0][0]
# __________________________________________________________________________________________________
# conv_1 (QuantizedConv2D)        (1, 64, None, None)  18432       conv_0_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_1_bn (BatchNormalization)  (1, 64, None, None)  256         conv_1[0][0]
# __________________________________________________________________________________________________
# conv_1_mish (ReLU)              (1, 64, None, None)  0           conv_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_1_mish_qdq (QDQ)           (1, 64, None, None)  1           conv_1_mish[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_0 (QuantizedConv2D) (1, 64, None, None)  36864       conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_0_bn (BatchNormaliz (1, 64, None, None)  256         conv_2_conv_0[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_0_mish (ReLU)       (1, 64, None, None)  0           conv_2_conv_0_bn[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_0_mish_qdq (QDQ)    (1, 64, None, None)  1           conv_2_conv_0_mish[0][0]
# __________________________________________________________________________________________________
# conv_2_split_0 (Split)          (1, 32, None, None)  0           conv_2_conv_0_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_split_0_qdq (QDQ)        (1, 32, None, None)  1           conv_2_split_0[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_1 (QuantizedConv2D) (1, 32, None, None)  9216        conv_2_split_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_1_bn (BatchNormaliz (1, 32, None, None)  128         conv_2_conv_1[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_1_mish (ReLU)       (1, 32, None, None)  0           conv_2_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_1_mish_qdq (QDQ)    (1, 32, None, None)  1           conv_2_conv_1_mish[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_2 (QuantizedConv2D) (1, 32, None, None)  9216        conv_2_conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_2_bn (BatchNormaliz (1, 32, None, None)  128         conv_2_conv_2[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_2_mish (ReLU)       (1, 32, None, None)  0           conv_2_conv_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_2_mish_qdq (QDQ)    (1, 32, None, None)  1           conv_2_conv_2_mish[0][0]
# __________________________________________________________________________________________________
# conv_2_concat_0 (Concatenate)   (1, 64, None, None)  0           conv_2_conv_2_mish_qdq[0][0]
#                                                                  conv_2_conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_concat_0_qdq (QDQ)       (1, 64, None, None)  1           conv_2_concat_0[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_3 (QuantizedConv2D) (1, 64, None, None)  4096        conv_2_concat_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_3_bn (BatchNormaliz (1, 64, None, None)  256         conv_2_conv_3[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_3_mish (ReLU)       (1, 64, None, None)  0           conv_2_conv_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_2_conv_3_mish_qdq (QDQ)    (1, 64, None, None)  1           conv_2_conv_3_mish[0][0]
# __________________________________________________________________________________________________
# conv_2_concat_1 (Concatenate)   (1, 128, None, None) 0           conv_2_conv_0_mish_qdq[0][0]
#                                                                  conv_2_conv_3_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_concat_1_qdq (QDQ)       (1, 128, None, None) 1           conv_2_concat_1[0][0]
# __________________________________________________________________________________________________
# conv_2_pool_0 (MaxPooling2D)    (1, 128, None, None) 0           conv_2_concat_1_qdq[0][0]
# __________________________________________________________________________________________________
# conv_2_pool_0_qdq (QDQ)         (1, 128, None, None) 1           conv_2_pool_0[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_0 (QuantizedConv2D) (1, 128, None, None) 147456      conv_2_pool_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_0_bn (BatchNormaliz (1, 128, None, None) 512         conv_3_conv_0[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_0_mish (ReLU)       (1, 128, None, None) 0           conv_3_conv_0_bn[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_0_mish_qdq (QDQ)    (1, 128, None, None) 1           conv_3_conv_0_mish[0][0]
# __________________________________________________________________________________________________
# conv_3_split_0 (Split)          (1, 64, None, None)  0           conv_3_conv_0_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_split_0_qdq (QDQ)        (1, 64, None, None)  1           conv_3_split_0[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_1 (QuantizedConv2D) (1, 64, None, None)  36864       conv_3_split_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_1_bn (BatchNormaliz (1, 64, None, None)  256         conv_3_conv_1[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_1_mish (ReLU)       (1, 64, None, None)  0           conv_3_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_1_mish_qdq (QDQ)    (1, 64, None, None)  1           conv_3_conv_1_mish[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_2 (QuantizedConv2D) (1, 64, None, None)  36864       conv_3_conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_2_bn (BatchNormaliz (1, 64, None, None)  256         conv_3_conv_2[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_2_mish (ReLU)       (1, 64, None, None)  0           conv_3_conv_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_2_mish_qdq (QDQ)    (1, 64, None, None)  1           conv_3_conv_2_mish[0][0]
# __________________________________________________________________________________________________
# conv_3_concat_0 (Concatenate)   (1, 128, None, None) 0           conv_3_conv_2_mish_qdq[0][0]
#                                                                  conv_3_conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_concat_0_qdq (QDQ)       (1, 128, None, None) 1           conv_3_concat_0[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_3 (QuantizedConv2D) (1, 128, None, None) 16384       conv_3_concat_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_3_bn (BatchNormaliz (1, 128, None, None) 512         conv_3_conv_3[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_3_mish (ReLU)       (1, 128, None, None) 0           conv_3_conv_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_3_mish_qdq (QDQ)    (1, 128, None, None) 1           conv_3_conv_3_mish[0][0]
# __________________________________________________________________________________________________
# conv_3_concat_1 (Concatenate)   (1, 256, None, None) 0           conv_3_conv_0_mish_qdq[0][0]
#                                                                  conv_3_conv_3_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_concat_1_qdq (QDQ)       (1, 256, None, None) 1           conv_3_concat_1[0][0]
# __________________________________________________________________________________________________
# conv_3_pool_0 (MaxPooling2D)    (1, 256, None, None) 0           conv_3_concat_1_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_pool_0_qdq (QDQ)         (1, 256, None, None) 1           conv_3_pool_0[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_0 (QuantizedConv2D) (1, 256, None, None) 589824      conv_3_pool_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_0_bn (BatchNormaliz (1, 256, None, None) 1024        conv_4_conv_0[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_0_mish (ReLU)       (1, 256, None, None) 0           conv_4_conv_0_bn[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_0_mish_qdq (QDQ)    (1, 256, None, None) 1           conv_4_conv_0_mish[0][0]
# __________________________________________________________________________________________________
# conv_4_split_0 (Split)          (1, 128, None, None) 0           conv_4_conv_0_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_split_0_qdq (QDQ)        (1, 128, None, None) 1           conv_4_split_0[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_1 (QuantizedConv2D) (1, 128, None, None) 147456      conv_4_split_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_1_bn (BatchNormaliz (1, 128, None, None) 512         conv_4_conv_1[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_1_mish (ReLU)       (1, 128, None, None) 0           conv_4_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_1_mish_qdq (QDQ)    (1, 128, None, None) 1           conv_4_conv_1_mish[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_2 (QuantizedConv2D) (1, 128, None, None) 147456      conv_4_conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_2_bn (BatchNormaliz (1, 128, None, None) 512         conv_4_conv_2[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_2_mish (ReLU)       (1, 128, None, None) 0           conv_4_conv_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_2_mish_qdq (QDQ)    (1, 128, None, None) 1           conv_4_conv_2_mish[0][0]
# __________________________________________________________________________________________________
# conv_4_concat_0 (Concatenate)   (1, 256, None, None) 0           conv_4_conv_2_mish_qdq[0][0]
#                                                                  conv_4_conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_concat_0_qdq (QDQ)       (1, 256, None, None) 1           conv_4_concat_0[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_3 (QuantizedConv2D) (1, 256, None, None) 65536       conv_4_concat_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_3_bn (BatchNormaliz (1, 256, None, None) 1024        conv_4_conv_3[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_3_mish (ReLU)       (1, 256, None, None) 0           conv_4_conv_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_3_mish_qdq (QDQ)    (1, 256, None, None) 1           conv_4_conv_3_mish[0][0]
# __________________________________________________________________________________________________
# conv_4_concat_1 (Concatenate)   (1, 512, None, None) 0           conv_4_conv_0_mish_qdq[0][0]
#                                                                  conv_4_conv_3_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_concat_1_qdq (QDQ)       (1, 512, None, None) 1           conv_4_concat_1[0][0]
# __________________________________________________________________________________________________
# conv_4_pool_0 (MaxPooling2D)    (1, 512, None, None) 0           conv_4_concat_1_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_pool_0_qdq (QDQ)         (1, 512, None, None) 1           conv_4_pool_0[0][0]
# __________________________________________________________________________________________________
# conv_5 (QuantizedConv2D)        (1, 512, None, None) 2359296     conv_4_pool_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_5_bn (BatchNormalization)  (1, 512, None, None) 2048        conv_5[0][0]
# __________________________________________________________________________________________________
# conv_5_mish (ReLU)              (1, 512, None, None) 0           conv_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_5_mish_qdq (QDQ)           (1, 512, None, None) 1           conv_5_mish[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_1 (QuantizedConv2D)  (1, 256, None, None) 131072      conv_5_mish_qdq[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_1_bn (BatchNormaliza (1, 256, None, None) 1024        yolo_conv1_1[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_1_lrelu (ReLU)       (1, 256, None, None) 0           yolo_conv1_1_bn[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_1_lrelu_qdq (QDQ)    (1, 256, None, None) 1           yolo_conv1_1_lrelu[0][0]
# __________________________________________________________________________________________________
# yolo_conv2 (QuantizedConv2D)    (1, 128, None, None) 32768       yolo_conv1_1_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# yolo_conv2_bn (BatchNormalizati (1, 128, None, None) 512         yolo_conv2[0][0]
# __________________________________________________________________________________________________
# yolo_conv2_lrelu (ReLU)         (1, 128, None, None) 0           yolo_conv2_bn[0][0]
# __________________________________________________________________________________________________
# yolo_conv2_lrelu_qdq (QDQ)      (1, 128, None, None) 1           yolo_conv2_lrelu[0][0]
# __________________________________________________________________________________________________
# upsample0 (UpSampling2D)        (1, 128, None, None) 0           yolo_conv2_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# upsample0_qdq (QDQ)             (1, 128, None, None) 1           upsample0[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (1, 384, None, None) 0           upsample0_qdq[0][0]
#                                                                  conv_4_conv_3_mish_qdq[0][0]
# __________________________________________________________________________________________________
# concatenate_2_qdq (QDQ)         (1, 384, None, None) 1           concatenate_2[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_6 (QuantizedConv2D)  (1, 512, None, None) 1179648     yolo_conv1_1_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# yolo_conv3_6 (QuantizedConv2D)  (1, 256, None, None) 884736      concatenate_2_qdq[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_6_bn (BatchNormaliza (1, 512, None, None) 2048        yolo_conv1_6[0][0]
# __________________________________________________________________________________________________
# yolo_conv3_6_bn (BatchNormaliza (1, 256, None, None) 1024        yolo_conv3_6[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_6_lrelu (ReLU)       (1, 512, None, None) 0           yolo_conv1_6_bn[0][0]
# __________________________________________________________________________________________________
# yolo_conv3_6_lrelu (ReLU)       (1, 256, None, None) 0           yolo_conv3_6_bn[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_6_lrelu_qdq (QDQ)    (1, 512, None, None) 1           yolo_conv1_6_lrelu[0][0]
# __________________________________________________________________________________________________
# yolo_conv3_6_lrelu_qdq (QDQ)    (1, 256, None, None) 1           yolo_conv3_6_lrelu[0][0]
# __________________________________________________________________________________________________
# conv_big_object (Conv2D)        (1, 18, None, None)  9234        yolo_conv1_6_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# conv_mid_object (Conv2D)        (1, 18, None, None)  4626        yolo_conv3_6_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# bg_permute (Permute)            (1, None, None, 18)  0           conv_big_object[0][0]
# __________________________________________________________________________________________________
# md_permute (Permute)            (1, None, None, 18)  0           conv_mid_object[0][0]
# __________________________________________________________________________________________________
# bg_reshape (Reshape)            (1, None, 6)         0           bg_permute[0][0]
# __________________________________________________________________________________________________
# md_reshape (Reshape)            (1, None, 6)         0           md_permute[0][0]
# __________________________________________________________________________________________________
# bg_anchor (YOLOAnchorBox)       (1, None, 6)         0           conv_big_object[0][0]
# __________________________________________________________________________________________________
# bg_bbox_processor (BBoxPostProc (1, None, 6)         0           bg_reshape[0][0]
# __________________________________________________________________________________________________
# md_anchor (YOLOAnchorBox)       (1, None, 6)         0           conv_mid_object[0][0]
# __________________________________________________________________________________________________
# md_bbox_processor (BBoxPostProc (1, None, 6)         0           md_reshape[0][0]
# __________________________________________________________________________________________________
# encoded_bg (Concatenate)        (1, None, 12)        0           bg_anchor[0][0]
#                                                                  bg_bbox_processor[0][0]
# __________________________________________________________________________________________________
# encoded_md (Concatenate)        (1, None, 12)        0           md_anchor[0][0]
#                                                                  md_bbox_processor[0][0]
# __________________________________________________________________________________________________
# encoded_detections (Concatenate (1, None, 12)        0           encoded_bg[0][0]
#                                                                  encoded_md[0][0]
# ==================================================================================================
# Total params: 5,880,358
# Trainable params: 5,874,116
# Non-trainable params: 6,242
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# INFO: Starting Training Loop.
# Epoch 1/80
# 104/104 [==============================] - 84s 807ms/step - loss: 12.4802
# 641fb48b811f:168:231 [0] NCCL INFO Bootstrap : Using eth0:172.17.0.4<0>
# 641fb48b811f:168:231 [0] NCCL INFO NET/Plugin: Failed to find ncclNetPlugin_v6 symbol.
# 641fb48b811f:168:231 [0] NCCL INFO NET/Plugin: Loaded net plugin NCCL RDMA Plugin (v5)
# 641fb48b811f:168:231 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v6 symbol.
# 641fb48b811f:168:231 [0] NCCL INFO NET/Plugin: Loaded coll plugin SHARP (v5)
# 641fb48b811f:168:231 [0] NCCL INFO cudaDriverVersion 11010
# NCCL version 2.15.1+cuda11.8
# 641fb48b811f:168:231 [0] NCCL INFO Plugin Path : /opt/hpcx/nccl_rdma_sharp_plugin/lib/libnccl-net.so
# 641fb48b811f:168:231 [0] NCCL INFO P2P plugin IBext
# 641fb48b811f:168:231 [0] NCCL INFO NET/IB : No device found.
# 641fb48b811f:168:231 [0] NCCL INFO NET/IB : No device found.
# 641fb48b811f:168:231 [0] NCCL INFO NET/Socket : Using [0]eth0:172.17.0.4<0>
# 641fb48b811f:168:231 [0] NCCL INFO Using network Socket
# 641fb48b811f:168:231 [0] NCCL INFO Channel 00/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 01/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 02/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 03/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 04/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 05/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 06/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 07/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 08/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 09/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 10/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 11/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 12/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 13/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 14/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 15/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 16/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 17/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 18/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 19/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 20/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 21/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 22/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 23/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 24/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 25/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 26/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 27/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 28/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 29/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 30/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Channel 31/32 :    0
# 641fb48b811f:168:231 [0] NCCL INFO Trees [0] -1/-1/-1->0->-1 [1] -1/-1/-1->0->-1 [2] -1/-1/-1->0->-1 [3] -1/-1/-1->0->-1 [4] -1/-1/-1->0->-1 [5] -1/-1/-1->0->-1 [6] -1/-1/-1->0->-1 [7] -1/-1/-1->0->-1 [8] -1/-1/-1->0->-1 [9] -1/-1/-1->0->-1 [10] -1/-1/-1->0->-1 [11] -1/-1/-1->0->-1 [12] -1/-1/-1->0->-1 [13] -1/-1/-1->0->-1 [14] -1/-1/-1->0->-1 [15] -1/-1/-1->0->-1 [16] -1/-1/-1->0->-1 [17] -1/-1/-1->0->-1 [18] -1/-1/-1->0->-1 [19] -1/-1/-1->0->-1 [20] -1/-1/-1->0->-1 [21] -1/-1/-1->0->-1 [22] -1/-1/-1->0->-1 [23] -1/-1/-1->0->-1 [24] -1/-1/-1->0->-1 [25] -1/-1/-1->0->-1 [26] -1/-1/-1->0->-1 [27] -1/-1/-1->0->-1 [28] -1/-1/-1->0->-1 [29] -1/-1/-1->0->-1 [30] -1/-1/-1->0->-1 [31] -1/-1/-1->0->-1
# 641fb48b811f:168:231 [0] NCCL INFO Connected all rings
# 641fb48b811f:168:231 [0] NCCL INFO Connected all trees
# 641fb48b811f:168:231 [0] NCCL INFO 32 coll channels, 32 p2p channels, 32 p2p channels per peer
# 641fb48b811f:168:231 [0] NCCL INFO comm 0x7fcf94424f80 rank 0 nranks 1 cudaDev 0 busId 1000 - Init COMPLETE
# INFO: Training loop in progress
# Epoch 2/80
# 104/104 [==============================] - 50s 478ms/step - loss: 12.2522
# INFO: Training loop in progress
# Epoch 3/80
# 104/104 [==============================] - 51s 492ms/step - loss: 13.5716
# INFO: Training loop in progress
# Epoch 4/80
# 104/104 [==============================] - 49s 476ms/step - loss: 12.4276
# INFO: Training loop in progress
# Epoch 5/80
# 104/104 [==============================] - 50s 476ms/step - loss: 11.2993
# INFO: Training loop in progress
# Epoch 6/80
# 104/104 [==============================] - 49s 469ms/step - loss: 11.5704
# INFO: Training loop in progress
# Epoch 7/80
# 104/104 [==============================] - 45s 432ms/step - loss: 11.5800
# INFO: Training loop in progress
# Epoch 8/80
# 104/104 [==============================] - 48s 460ms/step - loss: 12.6449
# INFO: Training loop in progress
# Epoch 9/80
# 104/104 [==============================] - 42s 406ms/step - loss: 10.9272
# INFO: Training loop in progress
# Epoch 10/80
# 104/104 [==============================] - 52s 495ms/step - loss: 11.0478
# Producing predictions: 100%|████████████████████| 29/29 [00:03<00:00,  9.25it/s]
# Start to calculate AP for each class
# *******************************
# airpods       AP    0.94142
#               mAP   0.94142
# *******************************
# Validation loss: 3.6862680912017822
# INFO: Evaluation metrics generated.
#
# Epoch 00010: saving model to /workspace/tao-experiments/yolo_v4_tiny/experiment_dir_retrain/weights/yolov4_cspdarknet_tiny_epoch_010.tlt
# INFO: Training loop in progress
# Epoch 11/80
# 104/104 [==============================] - 45s 430ms/step - loss: 10.4769
# INFO: Training loop in progress
# Epoch 12/80
# 104/104 [==============================] - 44s 423ms/step - loss: 10.5421
# INFO: Training loop in progress
# Epoch 13/80
# 104/104 [==============================] - 46s 447ms/step - loss: 10.4461
# INFO: Training loop in progress
# Epoch 14/80
# 104/104 [==============================] - 46s 439ms/step - loss: 9.7886
# INFO: Training loop in progress
# Epoch 15/80
# 104/104 [==============================] - 43s 416ms/step - loss: 10.3524
# INFO: Training loop in progress
# Epoch 16/80
# 104/104 [==============================] - 44s 423ms/step - loss: 9.9604
# INFO: Training loop in progress
# Epoch 66/80
# 104/104 [==============================] - 45s 434ms/step - loss: 5.1429
# INFO: Training loop in progress
# Epoch 67/80
# 104/104 [==============================] - 45s 432ms/step - loss: 5.3052
# INFO: Training loop in progress
# Epoch 68/80
# 104/104 [==============================] - 45s 434ms/step - loss: 5.4938
# INFO: Training loop in progress
# Epoch 69/80
# 104/104 [==============================] - 45s 432ms/step - loss: 5.6702
# INFO: Training loop in progress
# Epoch 70/80
# 104/104 [==============================] - 45s 434ms/step - loss: 5.7016
# Producing predictions: 100%|████████████████████| 29/29 [00:01<00:00, 16.34it/s]
# Start to calculate AP for each class
# *******************************
# airpods       AP    0.99697
#               mAP   0.99697
# *******************************
# Validation loss: 1.7463485865757382
# INFO: Evaluation metrics generated.
#
# Epoch 00070: saving model to /workspace/tao-experiments/yolo_v4_tiny/experiment_dir_retrain/weights/yolov4_cspdarknet_tiny_epoch_070.tlt
# INFO: Training loop in progress
# Epoch 71/80
# 104/104 [==============================] - 42s 403ms/step - loss: 5.1549
# INFO: Training loop in progress
# Epoch 72/80
# 104/104 [==============================] - 45s 434ms/step - loss: 4.9603
# INFO: Training loop in progress
# Epoch 73/80
# 104/104 [==============================] - 45s 434ms/step - loss: 5.5705
# INFO: Training loop in progress
# Epoch 74/80
# 104/104 [==============================] - 45s 433ms/step - loss: 5.5881
# INFO: Training loop in progress
# Epoch 75/80
# 104/104 [==============================] - 47s 455ms/step - loss: 5.2599
# INFO: Training loop in progress
# Epoch 76/80
# 104/104 [==============================] - 45s 429ms/step - loss: 4.3002
# INFO: Training loop in progress
# Epoch 77/80
# 104/104 [==============================] - 43s 417ms/step - loss: 5.2008
# INFO: Training loop in progress
# Epoch 78/80
# 104/104 [==============================] - 45s 434ms/step - loss: 5.0048
# INFO: Training loop in progress
# Epoch 79/80
# 104/104 [==============================] - 45s 431ms/step - loss: 5.2451
# INFO: Training loop in progress
# Epoch 80/80
# 104/104 [==============================] - 45s 435ms/step - loss: 4.7006
# Producing predictions: 100%|████████████████████| 29/29 [00:01<00:00, 14.97it/s]
# Start to calculate AP for each class
# *******************************
# airpods       AP    0.98827
#               mAP   0.98827
# *******************************
# Validation loss: 2.160589877901406
# INFO: Evaluation metrics generated.
#
# Epoch 00080: saving model to /workspace/tao-experiments/yolo_v4_tiny/experiment_dir_retrain/weights/yolov4_cspdarknet_tiny_epoch_080.tlt
# INFO: Training loop in progress
# INFO: Training loop complete.
# INFO: YOLO_V4 training finished successfully.
# INFO: Training finished successfully.
# 641fb48b811f:168:231 [0] NCCL INFO comm 0x7fcf94424f80 rank 0 nranks 1 cudaDev 0 busId 1000 - Destroy COMPLETE
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error [Errno -2] Name or service not known>
# Execution status: PASS
# 2023-04-06 11:52:10,973 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %%
# Listing the newly retrained model.
# !ls -rlt $LOCAL_EXPERIMENT_DIR/experiment_dir_retrain/weights
# Out:
# total 553920
# -rw-r--r-- 1 root root 70901440 Apr  6 10:59 yolov4_cspdarknet_tiny_epoch_010.tlt
# -rw-r--r-- 1 root root 70901440 Apr  6 11:06 yolov4_cspdarknet_tiny_epoch_020.tlt
# -rw-r--r-- 1 root root 70901440 Apr  6 11:14 yolov4_cspdarknet_tiny_epoch_030.tlt
# -rw-r--r-- 1 root root 70901440 Apr  6 11:21 yolov4_cspdarknet_tiny_epoch_040.tlt
# -rw-r--r-- 1 root root 70901440 Apr  6 11:29 yolov4_cspdarknet_tiny_epoch_050.tlt
# -rw-r--r-- 1 root root 70901440 Apr  6 11:37 yolov4_cspdarknet_tiny_epoch_060.tlt
# -rw-r--r-- 1 root root 70901440 Apr  6 11:44 yolov4_cspdarknet_tiny_epoch_070.tlt
# -rw-r--r-- 1 root root 70901440 Apr  6 11:52 yolov4_cspdarknet_tiny_epoch_080.tlt

# %%
# Now check the evaluation stats in the csv file and pick the model with highest eval accuracy.
# !cat $LOCAL_EXPERIMENT_DIR/experiment_dir_retr
concat_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_3_bn (BatchNormaliz (None, 128, 48, 156) 512         conv_3_conv_3[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_3_mish (ReLU)       (None, 128, 48, 156) 0           conv_3_conv_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_3_conv_3_mish_qdq (QDQ)    (None, 128, 48, 156) 1           conv_3_conv_3_mish[0][0]
# __________________________________________________________________________________________________
# conv_3_concat_1 (Concatenate)   (None, 256, 48, 156) 0           conv_3_conv_0_mish_qdq[0][0]
#                                                                  conv_3_conv_3_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_concat_1_qdq (QDQ)       (None, 256, 48, 156) 1           conv_3_concat_1[0][0]
# __________________________________________________________________________________________________
# conv_3_pool_0 (MaxPooling2D)    (None, 256, 24, 78)  0           conv_3_concat_1_qdq[0][0]
# __________________________________________________________________________________________________
# conv_3_pool_0_qdq (QDQ)         (None, 256, 24, 78)  1           conv_3_pool_0[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_0 (QuantizedConv2D) (None, 256, 24, 78)  589824      conv_3_pool_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_0_bn (BatchNormaliz (None, 256, 24, 78)  1024        conv_4_conv_0[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_0_mish (ReLU)       (None, 256, 24, 78)  0           conv_4_conv_0_bn[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_0_mish_qdq (QDQ)    (None, 256, 24, 78)  1           conv_4_conv_0_mish[0][0]
# __________________________________________________________________________________________________
# conv_4_split_0 (Split)          (None, 128, 24, 78)  0           conv_4_conv_0_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_split_0_qdq (QDQ)        (None, 128, 24, 78)  1           conv_4_split_0[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_1 (QuantizedConv2D) (None, 128, 24, 78)  147456      conv_4_split_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_1_bn (BatchNormaliz (None, 128, 24, 78)  512         conv_4_conv_1[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_1_mish (ReLU)       (None, 128, 24, 78)  0           conv_4_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_1_mish_qdq (QDQ)    (None, 128, 24, 78)  1           conv_4_conv_1_mish[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_2 (QuantizedConv2D) (None, 128, 24, 78)  147456      conv_4_conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_2_bn (BatchNormaliz (None, 128, 24, 78)  512         conv_4_conv_2[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_2_mish (ReLU)       (None, 128, 24, 78)  0           conv_4_conv_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_2_mish_qdq (QDQ)    (None, 128, 24, 78)  1           conv_4_conv_2_mish[0][0]
# __________________________________________________________________________________________________
# conv_4_concat_0 (Concatenate)   (None, 256, 24, 78)  0           conv_4_conv_2_mish_qdq[0][0]
#                                                                  conv_4_conv_1_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_concat_0_qdq (QDQ)       (None, 256, 24, 78)  1           conv_4_concat_0[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_3 (QuantizedConv2D) (None, 256, 24, 78)  65536       conv_4_concat_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_3_bn (BatchNormaliz (None, 256, 24, 78)  1024        conv_4_conv_3[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_3_mish (ReLU)       (None, 256, 24, 78)  0           conv_4_conv_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_4_conv_3_mish_qdq (QDQ)    (None, 256, 24, 78)  1           conv_4_conv_3_mish[0][0]
# __________________________________________________________________________________________________
# conv_4_concat_1 (Concatenate)   (None, 512, 24, 78)  0           conv_4_conv_0_mish_qdq[0][0]
#                                                                  conv_4_conv_3_mish_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_concat_1_qdq (QDQ)       (None, 512, 24, 78)  1           conv_4_concat_1[0][0]
# __________________________________________________________________________________________________
# conv_4_pool_0 (MaxPooling2D)    (None, 512, 12, 39)  0           conv_4_concat_1_qdq[0][0]
# __________________________________________________________________________________________________
# conv_4_pool_0_qdq (QDQ)         (None, 512, 12, 39)  1           conv_4_pool_0[0][0]
# __________________________________________________________________________________________________
# conv_5 (QuantizedConv2D)        (None, 512, 12, 39)  2359296     conv_4_pool_0_qdq[0][0]
# __________________________________________________________________________________________________
# conv_5_bn (BatchNormalization)  (None, 512, 12, 39)  2048        conv_5[0][0]
# __________________________________________________________________________________________________
# conv_5_mish (ReLU)              (None, 512, 12, 39)  0           conv_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_5_mish_qdq (QDQ)           (None, 512, 12, 39)  1           conv_5_mish[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_1 (QuantizedConv2D)  (None, 256, 12, 39)  131072      conv_5_mish_qdq[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_1_bn (BatchNormaliza (None, 256, 12, 39)  1024        yolo_conv1_1[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_1_lrelu (ReLU)       (None, 256, 12, 39)  0           yolo_conv1_1_bn[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_1_lrelu_qdq (QDQ)    (None, 256, 12, 39)  1           yolo_conv1_1_lrelu[0][0]
# __________________________________________________________________________________________________
# yolo_conv2 (QuantizedConv2D)    (None, 128, 12, 39)  32768       yolo_conv1_1_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# yolo_conv2_bn (BatchNormalizati (None, 128, 12, 39)  512         yolo_conv2[0][0]
# __________________________________________________________________________________________________
# yolo_conv2_lrelu (ReLU)         (None, 128, 12, 39)  0           yolo_conv2_bn[0][0]
# __________________________________________________________________________________________________
# yolo_conv2_lrelu_qdq (QDQ)      (None, 128, 12, 39)  1           yolo_conv2_lrelu[0][0]
# __________________________________________________________________________________________________
# upsample0 (UpSampling2D)        (None, 128, 24, 78)  0           yolo_conv2_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# upsample0_qdq (QDQ)             (None, 128, 24, 78)  1           upsample0[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 384, 24, 78)  0           upsample0_qdq[0][0]
#                                                                  conv_4_conv_3_mish_qdq[0][0]
# __________________________________________________________________________________________________
# concatenate_2_qdq (QDQ)         (None, 384, 24, 78)  1           concatenate_2[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_6 (QuantizedConv2D)  (None, 512, 12, 39)  1179648     yolo_conv1_1_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# yolo_conv3_6 (QuantizedConv2D)  (None, 256, 24, 78)  884736      concatenate_2_qdq[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_6_bn (BatchNormaliza (None, 512, 12, 39)  2048        yolo_conv1_6[0][0]
# __________________________________________________________________________________________________
# yolo_conv3_6_bn (BatchNormaliza (None, 256, 24, 78)  1024        yolo_conv3_6[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_6_lrelu (ReLU)       (None, 512, 12, 39)  0           yolo_conv1_6_bn[0][0]
# __________________________________________________________________________________________________
# yolo_conv3_6_lrelu (ReLU)       (None, 256, 24, 78)  0           yolo_conv3_6_bn[0][0]
# __________________________________________________________________________________________________
# yolo_conv1_6_lrelu_qdq (QDQ)    (None, 512, 12, 39)  1           yolo_conv1_6_lrelu[0][0]
# __________________________________________________________________________________________________
# yolo_conv3_6_lrelu_qdq (QDQ)    (None, 256, 24, 78)  1           yolo_conv3_6_lrelu[0][0]
# __________________________________________________________________________________________________
# conv_big_object (Conv2D)        (None, 18, 12, 39)   9234        yolo_conv1_6_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# conv_mid_object (Conv2D)        (None, 18, 24, 78)   4626        yolo_conv3_6_lrelu_qdq[0][0]
# __________________________________________________________________________________________________
# bg_permute (Permute)            (None, 12, 39, 18)   0           conv_big_object[0][0]
# __________________________________________________________________________________________________
# md_permute (Permute)            (None, 24, 78, 18)   0           conv_mid_object[0][0]
# __________________________________________________________________________________________________
# bg_reshape (Reshape)            (None, 1404, 6)      0           bg_permute[0][0]
# __________________________________________________________________________________________________
# md_reshape (Reshape)            (None, 5616, 6)      0           md_permute[0][0]
# __________________________________________________________________________________________________
# bg_anchor (YOLOAnchorBox)       (None, 1404, 6)      0           conv_big_object[0][0]
# __________________________________________________________________________________________________
# bg_bbox_processor (BBoxPostProc (None, 1404, 6)      0           bg_reshape[0][0]
# __________________________________________________________________________________________________
# md_anchor (YOLOAnchorBox)       (None, 5616, 6)      0           conv_mid_object[0][0]
# __________________________________________________________________________________________________
# md_bbox_processor (BBoxPostProc (None, 5616, 6)      0           md_reshape[0][0]
# __________________________________________________________________________________________________
# encoded_bg (Concatenate)        (None, 1404, 12)     0           bg_anchor[0][0]
#                                                                  bg_bbox_processor[0][0]
# __________________________________________________________________________________________________
# encoded_md (Concatenate)        (None, 5616, 12)     0           md_anchor[0][0]
#                                                                  md_bbox_processor[0][0]
# __________________________________________________________________________________________________
# encoded_detections (Concatenate (None, 7020, 12)     0           encoded_bg[0][0]
#                                                                  encoded_md[0][0]
# __________________________________________________________________________________________________
# decoded_predictions (YOLOv4Deco (None, 7020, 5)      0           encoded_detections[0][0]
# __________________________________________________________________________________________________
# NMS (NMSLayer)                  (None, 200, 6)       0           decoded_predictions[0][0]
# ==================================================================================================
# Total params: 5,880,358
# Trainable params: 5,874,116
# Non-trainable params: 6,242
# __________________________________________________________________________________________________
# Using TLT model for inference, setting batch size to the one in eval_config: 1
# 2023-04-06 04:20:18,432 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Serial augmentation enabled = False
# 2023-04-06 04:20:18,433 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Pseudo sharding enabled = False
# 2023-04-06 04:20:18,433 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Max Image Dimensions (all sources): (0, 0)
# 2023-04-06 04:20:18,433 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: number of cpus: 20, io threads: 40, compute threads: 20, buffered batches: -1
# 2023-04-06 04:20:18,433 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: total dataset size 29, number of sources: 1, batch size per gpu: 1, steps: 29
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# 2023-04-06 04:20:18,459 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:Entity <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7f742011e898>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7f742011e898>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2023-04-06 04:20:18,490 [WARNING] tensorflow: Entity <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7f742011e898>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method YOLOv3TFRecordsParser.__call__ of <iva.yolo_v3.data_loader.yolo_v3_data_loader.YOLOv3TFRecordsParser object at 0x7f742011e898>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2023-04-06 04:20:18,504 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2023-04-06 04:20:18,691 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: False - shard 0 of 1
# 2023-04-06 04:20:18,695 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: sampling 1 datasets with weights:
# 2023-04-06 04:20:18,695 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 0 weight: 1.000000
# WARNING:tensorflow:Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f7442262518>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f7442262518>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2023-04-06 04:20:18,706 [WARNING] tensorflow: Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f7442262518>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f7442262518>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# Producing predictions: 100%|████████████████████| 29/29 [00:03<00:00,  8.16it/s]
# Start to calculate AP for each class
# *******************************
# airpods       AP    0.98827
#               mAP   0.98827
# *******************************
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error [Errno -2] Name or service not known>
# Execution status: PASS
# 2023-04-06 12:20:25,196 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %% [markdown]
# ## 9. Visualize inferences <a class="anchor" id="head-9"></a>
# In this section, we run the `infer` tool to generate inferences on the trained models and visualize the results.

# %%
# Copy some test images
# !mkdir -p $LOCAL_DATA_DIR/test_samples
# !cp $LOCAL_DATA_DIR/testing/image_2/00000* $LOCAL_DATA_DIR/test_samples/

# %%
# !echo $EPOCH
# Out:
# 080

# %%
# Running inference for detection on n images
# !tao yolo_v4_tiny inference -i $DATA_DOWNLOAD_DIR/test_samples \
                       -o $USER_EXPERIMENT_DIR/yolo_infer_images \
                       -e $SPECS_DIR/yolo_v4_tiny_retrain_kitti.txt \
                       -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/yolov4_cspdarknet_tiny_epoch_$EPOCH.tlt \
                       -l $USER_EXPERIMENT_DIR/yolo_infer_labels \
                       -k $KEY
# Out:
# 2023-04-06 12:23:14,347 [INFO] root: Registry: ['nvcr.io']
# 2023-04-06 12:23:14,379 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5
# 2023-04-06 12:23:14,388 [WARNING] tlt.components.docker_handler.docker_handler:
# Docker will run the commands as root. If you would like to retain your
# local host permissions, please add the "user":"UID:GID" in the
# DockerOptions portion of the "/home/hirain/.tao_mounts.json" file. You can obtain your
# users UID and GID by using the "id -u" and "id -g" commands on the
# terminal.
# Using TensorFlow backend.
# 2023-04-06 04:23:15.841451: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# 2023-04-06 04:23:20,490 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2023-04-06 04:23:20,490 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2023-04-06 04:23:20,492 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2023-04-06 04:23:21,147 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# 2023-04-06 04:23:21,159 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 2023-04-06 04:23:21,170 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/third_party/keras/tensorflow_backend.py:183: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 2023-04-06 04:23:21,281 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/third_party/keras/tensorflow_backend.py:183: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# 2023-04-06 04:23:21,514 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# 2023-04-06 04:23:21,745 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2023-04-06 04:23:21,745 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2023-04-06 04:23:21,745 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2023-04-06 04:23:22,067 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# 2023-04-06 04:23:22,068 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2023-04-06 04:23:22,286 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# 2023-04-06 04:23:22,570 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# 2023-04-06 04:23:23,545 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# 2023-04-06 04:23:23,844 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Using TLT model for inference, setting batch size to the one in eval_config: 1
# 100%|█████████████████████████████████████████████| 4/4 [00:02<00:00,  1.56it/s]
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error [Errno -2] Name or service not known>
# Execution status: PASS
# 2023-04-06 12:23:30,497 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %% [markdown]
# The `inference` tool produces two outputs.
# 1. Overlain images in `$LOCAL_EXPERIMENT_DIR/yolo_infer_images`
# 2. Frame by frame bbox labels in kitti format located in `$LOCAL_EXPERIMENT_DIR/yolo_infer_labels`

# %%
# Simple grid visualizer
#!pip3 install matplotlib==3.3.3
#import matplotlib.pyplot as plt
#import os
#from math import ceil
#valid_image_ext = ['.jpg', '.png', '.jpeg', '.ppm']

#def visualize_images(image_dir, num_cols=4, num_images=10):
#    output_path = os.path.join(os.environ['LOCAL_EXPERIMENT_DIR'], image_dir)
#    num_rows = int(ceil(float(num_images) / float(num_cols)))
#    f, axarr = plt.subplots(num_rows, num_cols, figsize=[80,30])
#    f.tight_layout()
#    a = [os.path.join(output_path, image) for image in os.listdir(output_path) 
#         if os.path.splitext(image)[1].lower() in valid_image_ext]
#    for idx, img_path in enumerate(a[:num_images]):
#        col_id = idx % num_cols
#        row_id = idx // num_cols
#        img = plt.imread(img_path)
#        axarr[row_id, col_id].imshow(img)

# %%
# Visualizing the sample images.
#OUTPUT_PATH = 'yolo_infer_images' # relative path from $USER_EXPERIMENT_DIR.
#COLS = 3 # number of columns in the visualizer grid.
#IMAGES = 9 # number of images to visualize.

#visualize_images(OUTPUT_PATH, num_cols=COLS, num_images=IMAGES)

# %% [markdown]
# ## 10. Model Export <a class="anchor" id="head-10"></a>

# %% [markdown]
# If you trained a non-QAT model, you may export in FP32, FP16 or INT8 mode using the code block below. For INT8, you need to provide calibration image directory.

# %%
# tao <task> export will fail if .etlt already exists. So we clear the export folder before tao <task> export
# !rm -rf $LOCAL_EXPERIMENT_DIR/export
# !mkdir -p $LOCAL_EXPERIMENT_DIR/export
# Export in FP32 mode. Change --data_type to fp16 for FP16 mode
# !tao yolo_v4_tiny export -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/yolov4_cspdarknet_tiny_epoch_$EPOCH.tlt \
                    -k $KEY \
                    -o $USER_EXPERIMENT_DIR/export/yolov4_cspdarknet_tiny_epoch_$EPOCH.etlt \
                    -e $SPECS_DIR/yolo_v4_tiny_retrain_kitti.txt \
                    --batch_size 16 \
                    --data_type fp32 \
                    --gen_ds_config

# Uncomment to export in INT8 mode (generate calibration cache file). 
#!tao yolo_v4_tiny export -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/yolov4_cspdarknet_tiny_epoch_$EPOCH.tlt  \
#                     -o $USER_EXPERIMENT_DIR/export/yolov4_cspdarknet_tiny_epoch_$EPOCH.etlt \
#                     -e $SPECS_DIR/yolo_v4_tiny_retrain_kitti.txt \
#                     -k $KEY \
#                     --cal_image_dir $DATA_DOWNLOAD_DIR/testing/image_2 \
#                     --data_type int8 \
#                     --batch_size 16 \
#                     --batches 10 \
#                     --cal_cache_file $USER_EXPERIMENT_DIR/export/cal.bin  \
#                     --cal_data_file $USER_EXPERIMENT_DIR/export/cal.tensorfile \
#                     --gen_ds_config
# Out:
# 2023-04-07 16:03:40,003 [INFO] root: Registry: ['nvcr.io']
# 2023-04-07 16:03:40,033 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5
# 2023-04-07 16:03:40,042 [WARNING] tlt.components.docker_handler.docker_handler:
# Docker will run the commands as root. If you would like to retain your
# local host permissions, please add the "user":"UID:GID" in the
# DockerOptions portion of the "/home/hirain/.tao_mounts.json" file. You can obtain your
# users UID and GID by using the "id -u" and "id -g" commands on the
# terminal.
# Using TensorFlow backend.
# 2023-04-07 08:03:41.577475: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2023-04-07 08:03:48,395 [INFO] iva.common.export.keras_exporter: Using input nodes: ['Input']
# 2023-04-07 08:03:48,395 [INFO] iva.common.export.keras_exporter: Using output nodes: ['BatchedNMS']
# The ONNX operator number change on the optimization: 320 -> 158
# 2023-04-07 08:04:28,709 [INFO] keras2onnx: The ONNX operator number change on the optimization: 320 -> 158
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error [Errno -2] Name or service not known>
# Execution status: PASS
# 2023-04-07 16:11:17,725 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %% [markdown]
# `Note:` In this example, for ease of execution we restrict the number of calibrating batches to 10. TAO Toolkit recommends the use of at least 10% of the training dataset for int8 calibration.
#
# If you train a QAT model, you may only export in INT8 mode using following code block. This generates an etlt file and the corresponding calibration cache. You can throw away the calibration cache and just use the etlt file in tao-converter or DeepStream for FP32 or FP16 mode. But please note this gives sub-optimal results. If you want to deploy in FP32 or FP16, you should disable QAT in training.

# %%
# Uncomment to export QAT model in INT8 mode (generate calibration cache file).
#!rm -rf $LOCAL_EXPERIMENT_DIR/export
#!mkdir -p $LOCAL_EXPERIMENT_DIR/export
#!tao yolo_v4_tiny export -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/yolov4_cspdarknet_tiny_epoch_$EPOCH.tlt  \
#                    -o $USER_EXPERIMENT_DIR/export/yolov4_cspdarknet_tiny_epoch_$EPOCH.etlt \
#                    -e $SPECS_DIR/yolo_v4_tiny_retrain_kitti.txt \
#                    -k $KEY \
#                    --data_type int8 \
#                    --cal_cache_file $USER_EXPERIMENT_DIR/export/cal.bin

# %%
print('Exported model:')
print('------------')
# !ls -lh $LOCAL_EXPERIMENT_DIR/export
# Out:
# Exported model:
# ------------
# total 23M
# -rw-r--r-- 1 root root   8 Apr  7 16:04 labels.txt
# -rw-r--r-- 1 root root 277 Apr  7 16:04 nvinfer_config.txt
# -rw-r--r-- 1 root root 23M Apr  7 16:04 yolov4_cspdarknet_tiny_epoch_080.etlt

# %% [markdown]
# Verify engine generation using the `tao-converter` utility included with the docker.
#
# The `tao-converter` produces optimized tensorrt engines for the platform that it resides on. Therefore, to get maximum performance, please instantiate this docker and execute the `tao-converter` command, with the exported `.etlt` file and calibration cache (for int8 mode) on your target device. The tao-converter utility included in this docker only works for x86 devices, with discrete NVIDIA GPU's.
#
# For the jetson devices, please download the tao-converter for jetson from the dev zone link [here](https://developer.nvidia.com/tao-converter).
#
# The -p argument in following command is the optimization profile. This should be in format `<input_node>,<min_shape>,<opt_shape>,<max_shape>`. In YOLO v4 Tiny, the three shapes should only have differences at the batch dimension

# %%
# Convert to TensorRT engine (FP32)
# !tao converter -k $KEY \
                  -p Input,1x3x384x1248,8x3x384x1248,16x3x384x1248 \
                  -e $USER_EXPERIMENT_DIR/export/trt.engine \
                  -t fp32 \
                  $USER_EXPERIMENT_DIR/export/yolov4_cspdarknet_tiny_epoch_$EPOCH.etlt

#Convert to TensorRT engine (FP16)
#!tao converter -k $KEY \
#                   -p Input,1x3x384x1248,8x3x384x1248,16x3x384x1248 \
#                   -e $USER_EXPERIMENT_DIR/export/trt.engine \
#                  -t fp16 \
#                   $USER_EXPERIMENT_DIR/export/yolov4_cspdarknet_tiny_epoch_$EPOCH.etlt

# Convert to TensorRT engine (INT8)
#!tao converter -k $KEY  \
#                   -p Input,1x3x384x1248,8x3x384x1248,16x3x384x1248 \
#                   -c $USER_EXPERIMENT_DIR/export/cal.bin \
#                   -e $USER_EXPERIMENT_DIR/export/trt.engine \
#                   -b 8 \
#                   -t int8 \
#                   $USER_EXPERIMENT_DIR/export/yolov4_cspdarknet_tiny_epoch_$EPOCH.etlt
# Out:
# 2023-04-07 16:23:23,865 [INFO] root: Registry: ['nvcr.io']
# 2023-04-07 16:23:23,896 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5
# 2023-04-07 16:23:23,906 [WARNING] tlt.components.docker_handler.docker_handler:
# Docker will run the commands as root. If you would like to retain your
# local host permissions, please add the "user":"UID:GID" in the
# DockerOptions portion of the "/home/hirain/.tao_mounts.json" file. You can obtain your
# users UID and GID by using the "id -u" and "id -g" commands on the
# terminal.
# [INFO] [MemUsageChange] Init CUDA: CPU +328, GPU +0, now: CPU 340, GPU 792 (MiB)
# [INFO] [MemUsageChange] Init builder kernel library: CPU +445, GPU +118, now: CPU 840, GPU 910 (MiB)
# [WARNING] CUDA lazy loading is not enabled. Enabling it can significantly reduce device memory usage. See `CUDA_MODULE_LOADING` in https://docs.nvidia.com/cuda/cuda-c-programming-guide/index.html#env-vars
# [INFO] ----------------------------------------------------------------
# [INFO] Input filename:   /tmp/fileBUy6gS
# [INFO] ONNX IR version:  0.0.8
# [INFO] Opset version:    15
# [INFO] Producer name:
# [INFO] Producer version:
# [INFO] Domain:
# [INFO] Model version:    0
# [INFO] Doc string:
# [INFO] ----------------------------------------------------------------
# [WARNING] onnx2trt_utils.cpp:377: Your ONNX model has been generated with INT64 weights, while TensorRT does not natively support INT64. Attempting to cast down to INT32.
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [WARNING] onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# [INFO] No importer registered for op: BatchedNMSDynamic_TRT. Attempting to import as plugin.
# [INFO] Searching for plugin: BatchedNMSDynamic_TRT, plugin_version: 1, plugin_namespace:
# [WARNING] builtin_op_importers.cpp:5227: Attribute caffeSemantics not found in plugin node! Ensure that the plugin creator has a default value defined or the engine may fail to build.
# [INFO] Successfully created plugin: BatchedNMSDynamic_TRT
# [INFO] Detected input dimensions from the model: (-1, 3, 384, 1248)
# [INFO] Model has dynamic shape. Setting up optimization profiles.
# [INFO] Using optimization profile min shape: (1, 3, 384, 1248) for input: Input
# [INFO] Using optimization profile opt shape: (8, 3, 384, 1248) for input: Input
# [INFO] Using optimization profile max shape: (16, 3, 384, 1248) for input: Input
# [INFO] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +858, GPU +360, now: CPU 1722, GPU 1270 (MiB)
# [INFO] [MemUsageChange] Init cuDNN: CPU +127, GPU +58, now: CPU 1849, GPU 1328 (MiB)
# [INFO] Local timing cache in use. Profiling results in this builder pass will not be stored.
# [INFO] Some tactics do not have sufficient workspace memory to run. Increasing workspace size will enable more tactics, please check verbose output for requested sizes.
# [INFO] Total Activation Memory: 1941181952
# [INFO] Detected 1 inputs and 4 output network tensors.
# [INFO] Total Host Persistent Memory: 70928
# [INFO] Total Device Persistent Memory: 236544
# [INFO] Total Scratch Memory: 3196928
# [INFO] [MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 13 MiB, GPU 887 MiB
# [INFO] [BlockAssignment] Started assigning block shifts. This will take 58 steps to complete.
# [INFO] [BlockAssignment] Algorithm ShiftNTopDown took 1.94769ms to assign 7 blocks to 58 nodes requiring 248092672 bytes.
# [INFO] Total Activation Memory: 248092672
# [INFO] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +8, now: CPU 2463, GPU 1598 (MiB)
# [INFO] [MemUsageChange] Init cuDNN: CPU +1, GPU +10, now: CPU 2464, GPU 1608 (MiB)
# [WARNING] TensorRT encountered issues when converting weights between types and that could affect accuracy.
# [WARNING] If this is not the desired behavior, please modify the weights or retrain with regularization to adjust the magnitude of the weights.
# [WARNING] Check verbose logs for the list of affected weights.
# [WARNING] - 20 weights are affected by this issue: Detected subnormal FP16 values.
# [WARNING] - 3 weights are affected by this issue: Detected values less than smallest positive FP16 subnormal value and converted them to the FP16 minimum subnormalized value.
# [INFO] [MemUsageChange] TensorRT-managed allocation in building engine: CPU +11, GPU +12, now: CPU 11, GPU 12 (MiB)
# 2023-04-07 16:30:03,609 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %%
print('Exported engine:')
print('------------')
# !ls -lh $LOCAL_EXPERIMENT_DIR/export/trt.engine
# Out:
# Exported engine:
# ------------
# -rw-r--r-- 1 root root 13M Apr  7 16:30 /home/hirain/cv_samples_v1.4.0/yolo_v4_tiny/export/trt.engine

# %% [markdown]
# ## 11. Verify the deployed model <a class="anchor" id="head-11"></a>
# Verify the converted engine by visualizing TensorRT inferences.

# %%
# Infer using TensorRT engine
# !tao yolo_v4_tiny inference -m $USER_EXPERIMENT_DIR/export/trt.engine \
                       -e $SPECS_DIR/yolo_v4_tiny_retrain_kitti.txt \
                       -i $DATA_DOWNLOAD_DIR/test_samples \
                       -o $USER_EXPERIMENT_DIR/yolo_infer_images \
                       -t 0.6
# Out:
# 2023-04-07 16:39:18,680 [INFO] root: Registry: ['nvcr.io']
# 2023-04-07 16:39:18,708 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5
# 2023-04-07 16:39:18,718 [WARNING] tlt.components.docker_handler.docker_handler:
# Docker will run the commands as root. If you would like to retain your
# local host permissions, please add the "user":"UID:GID" in the
# DockerOptions portion of the "/home/hirain/.tao_mounts.json" file. You can obtain your
# users UID and GID by using the "id -u" and "id -g" commands on the
# terminal.
# Using TensorFlow backend.
# 2023-04-07 08:39:20.046801: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# 2023-04-07 08:39:24,665 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2023-04-07 08:39:24,665 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2023-04-07 08:39:24,667 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# [04/07/2023-08:39:25] [TRT] [W] The getMaxBatchSize() function should not be used with an engine built from a network created with NetworkDefinitionCreationFlag::kEXPLICIT_BATCH flag. This function will always return 1.
# [04/07/2023-08:39:25] [TRT] [W] CUDA lazy loading is not enabled. Enabling it can significantly reduce device memory usage. See `CUDA_MODULE_LOADING` in https://docs.nvidia.com/cuda/cuda-c-programming-guide/index.html#env-vars
# Using TensorRT engine for inference, setting batch size to the one in eval_config: 1
# If your engine maximum batch size is smaller, change eval_config in spec file!
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00,  9.71it/s]
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error [Errno -2] Name or service not known>
# Execution status: PASS
# 2023-04-07 16:39:28,145 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %%
# Visualizing the sample images.
OUTPUT_PATH = 'yolo_infer_images' # relative path from $USER_EXPERIMENT_DIR.
COLS = 3 # number of columns in the visualizer grid.
IMAGES = 9 # number of images to visualize.

visualize_images(OUTPUT_PATH, num_cols=COLS, num_images=IMAGES)
